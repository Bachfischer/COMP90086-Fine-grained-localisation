# %%
# %load_ext autoreload
# %autoreload 2

from pathlib import Path

from hloc import extract_features, match_features, reconstruction, visualization, pairs_from_retrieval

# %% [markdown]
# ## Setup
# In this notebook, we will run SfM reconstruction from scratch on a set of images. We choose the [South-Building dataset](https://openaccess.thecvf.com/content_cvpr_2013/html/Hane_Joint_3D_Scene_2013_CVPR_paper.html) - we will download it later. First, we define some paths.

# %%
dataset = Path('datasets/COMP90086')
images = dataset / 'images/'

outputs = Path('outputs/COMP90086/')
sfm_pairs = outputs / 'pairs-manual-db-covis5.txt'
sfm_dir = outputs / 'sfm_superpoint+superglue'

feature_conf = extract_features.confs['superpoint_aachen']
matcher_conf = match_features.confs['superglue']

# %% [markdown]
# ## Download the dataset
# The dataset is simply a set of images. The intrinsic parameters will be extracted from the EXIF data, and refined with SfM.

# %% [markdown]
# ## Extract local features for database and query images

# %%
feature_path = extract_features.main(feature_conf, images, outputs)
# Out:
# [10/16/2021 06:08:05 INFO] Extracting local features with configuration:
# {'model': {'max_keypoints': 4096, 'name': 'superpoint', 'nms_radius': 3},
#  'output': 'feats-superpoint-n4096-r1024',
#  'preprocessing': {'grayscale': True, 'resize_max': 1024}}
# [10/16/2021 06:08:05 INFO] Found 8700 images in root datasets/COMP90086/images.
# Loaded SuperPoint model
# 100%|██████████| 8700/8700 [1:24:27<00:00,  1.72it/s]
# [10/16/2021 07:32:32 INFO] Finished exporting features.

# %% [markdown]
# ## Matching

# %%
match_path = match_features.main(
    matcher_conf, sfm_pairs, feature_conf['output'], outputs, exhaustive=False)
# Out:
# [10/16/2021 07:39:06 INFO] Matching local features with configuration:
# {'model': {'name': 'superglue',
#            'sinkhorn_iterations': 50,
#            'weights': 'outdoor'},
#  'output': 'matches-superglue'}
# Loaded SuperGlue model ("outdoor" weights)
# 100%|██████████| 30000/30000 [5:53:25<00:00,  1.41it/s]
# [10/16/2021 13:32:36 INFO] Finished exporting matches.

# %%
feature_path
# Out:
# PosixPath('outputs/COMP90086/feats-superpoint-n4096-r1024.h5')

# %% [markdown]
# ## SfM reconstruction
# Run COLMAP on the features and matches.

# %%
feature_path = outputs / 'feats-superpoint-n4096-r1024.h5'
match_path = outputs / 'feats-superpoint-n4096-r1024_matches-superglue_pairs-manual-db-covis5.h5'

reconstruction.main(sfm_dir, images / 'train', sfm_pairs, feature_path, match_path, skip_geometric_verification = True)
# Out:
# [10/16/2021 16:29:49 INFO] Creating an empty database...
# [10/16/2021 16:29:49 INFO] Importing images into the database...
#
# ==============================================================================
# Feature import
# ==============================================================================
#
# Processing file [1/7500]
#   Features:       0
# Processing file [2/7500]
#   Features:       0
# Processing file [3/7500]
#   Features:       0
# Processing file [4/7500]
#   Features:       0
# Processing file [5/7500]
#   Features:       0
# Processing file [6/7500]
#   Features:       0
# Processing file [7/7500]
#   Features:       0
# Processing file [8/7500]
#   Features:       0
# Processing file [9/7500]
#   Features:       0
# Processing file [10/7500]
#   Features:       0
# Processing file [11/7500]
#   Features:       0
# Processing file [12/7500]
#   Features:       0
# Processing file [13/7500]
#   Features:       0
# Processing file [14/7500]
#   Features:       0
# Processing file [15/7500]
#   Features:       0
# Processing file [16/7500]
#   Features:       0
# Processing file [17/7500]
#   Features:       0
# Processing file [18/7500]
#   Features:       0
# Processing file [19/7500]
#   Features:       0
# Processing file [20/7500]
#   Features:       0
# Processing file [21/7500]
#   Features:       0
# Processing file [22/7500]
#   Features:       0
# Processing file [23/7500]
#   Features:       0
# Processing file [24/7500]
#   Features:       0
# Processing file [25/7500]
#   Features:       0
# Processing file [26/7500]
#   Features:       0
# Processing file [27/7500]
#   Features:       0
# Processing file [28/7500]
#   Features:       0
# Processing file [29/7500]
#   Features:       0
# Processing file [30/7500]
#   Features:       0
# Processing file [31/7500]
#   Features:       0
# Processing file [32/7500]
#   Features:       0
# Processing file [33/7500]
#   Features:       0
# Processing file [34/7500]
#   Features:       0
# Processing file [35/7500]
#   Features:       0
# Processing file [36/7500]
#   Features:       0
# Processing file [37/7500]
#   Features:       0
# Processing file [38/7500]
#   Features:       0
# Processing file [39/7500]
#   Features:       0
# Processing file [40/7500]
#   Features:       0
# Processing file [41/7500]
#   Features:       0
# Processing file [42/7500]
#   Features:       0
# Processing file [43/7500]
#   Features:       0
# Processing file [44/7500]
#   Features:       0
# Processing file [45/7500]
#   Features:       0
# Processing file [46/7500]
#   Features:       0
# Processing file [47/7500]
#   Features:       0
# Processing file [48/7500]
#   Features:       0
# Processing file [49/7500]
#   Features:       0
# Processing file [50/7500]
#   Features:       0
# Processing file [51/7500]
#   Features:       0
# Processing file [52/7500]
#   Features:       0
# Processing file [53/7500]
#   Features:       0
# Processing file [54/7500]
#   Features:       0
# Processing file [55/7500]
#   Features:       0
# Processing file [56/7500]
#   Features:       0
# Processing file [57/7500]
#   Features:       0
# Processing file [58/7500]
#   Features:       0
# Processing file [59/7500]
#   Features:       0
# Processing file [60/7500]
#   Features:       0
# Processing file [61/7500]
#   Features:       0
# Processing file [62/7500]
#   Features:       0
# Processing file [63/7500]
#   Features:       0
# Processing file [64/7500]
#   Features:       0
# Processing file [65/7500]
#   Features:       0
# Processing file [66/7500]
#   Features:       0
# Processing file [67/7500]
#   Features:       0
# Processing file [68/7500]
#   Features:       0
# Processing file [69/7500]
#   Features:       0
# Processing file [70/7500]
#   Features:       0
# Processing file [71/7500]
#   Features:       0
# Processing file [72/7500]
#   Features:       0
# Processing file [73/7500]
#   Features:       0
# Processing file [74/7500]
#   Features:       0
# Processing file [75/7500]
#   Features:       0
# Processing file [76/7500]
#   Features:       0
# Processing file [77/7500]
#   Features:       0
# Processing file [78/7500]
#   Features:       0
# Processing file [79/7500]
#   Features:       0
# Processing file [80/7500]
#   Features:       0
# Processing file [81/7500]
#   Features:       0
# Processing file [82/7500]
#   Features:       0
# Processing file [83/7500]
#   Features:       0
# Processing file [84/7500]
#   Features:       0
# Processing file [85/7500]
#   Features:       0
# Processing file [86/7500]
#   Features:       0
# Processing file [87/7500]
#   Features:       0
# Processing file [88/7500]
#   Features:       0
# Processing file [89/7500]
#   Features:       0
# Processing file [90/7500]
#   Features:       0
# Processing file [91/7500]
#   Features:       0
# Processing file [92/7500]
#   Features:       0
# Processing file [93/7500]
#   Features:       0
# Processing file [94/7500]
#   Features:       0
# Processing file [95/7500]
#   Features:       0
# Processing file [96/7500]
#   Features:       0
# Processing file [97/7500]
#   Features:       0
# Processing file [98/7500]
#   Features:       0
# Processing file [99/7500]
#   Features:       0
# Processing file [100/7500]
#   Features:       0
# Processing file [101/7500]
#   Features:       0
# Processing file [102/7500]
#   Features:       0
# Processing file [103/7500]
#   Features:       0
# Processing file [104/7500]
#   Features:       0
# Processing file [105/7500]
#   Features:       0
# Processing file [106/7500]
#   Features:       0
# Processing file [107/7500]
#   Features:       0
# Processing file [108/7500]
#   Features:       0
# Processing file [109/7500]
#   Features:       0
# Processing file [110/7500]
#   Features:       0
# Processing file [111/7500]
#   Features:       0
# Processing file [112/7500]
#   Features:       0
# Processing file [113/7500]
#   Features:       0
# Processing file [114/7500]
#   Features:       0
# Processing file [115/7500]
#   Features:       0
# Processing file [116/7500]
#   Features:       0
# Processing file [117/7500]
#   Features:       0
# Processing file [118/7500]
#   Features:       0
# Processing file [119/7500]
#   Features:       0
# Processing file [120/7500]
#   Features:       0
# Processing file [121/7500]
#   Features:       0
# Processing file [122/7500]
#   Features:       0
# Processing file [123/7500]
#   Features:       0
# Processing file [124/7500]
#   Features:       0
# Processing file [125/7500]
#   Features:       0
# Processing file [126/7500]
#   Features:       0
# Processing file [127/7500]
#   Features:       0
# Processing file [128/7500]
#   Features:       0
# Processing file [129/7500]
#   Features:       0
# Processing file [130/7500]
#   Features:       0
# Processing file [131/7500]
#   Features:       0
# Processing file [132/7500]
#   Features:       0
# Processing file [133/7500]
#   Features:       0
# Processing file [134/7500]
#   Features:       0
# Processing file [135/7500]
#   Features:       0
# Processing file [136/7500]
#   Features:       0
# Processing file [137/7500]
#   Features:       0
# Processing file [138/7500]
#   Features:       0
# Processing file [139/7500]
#   Features:       0
# Processing file [140/7500]
#   Features:       0
# Processing file [141/7500]
#   Features:       0
# Processing file [142/7500]
#   Features:       0
# Processing file [143/7500]
#   Features:       0
# Processing file [144/7500]
#   Features:       0
# Processing file [145/7500]
#   Features:       0
# Processing file [146/7500]
#   Features:       0
# Processing file [147/7500]
#   Features:       0
# Processing file [148/7500]
#   Features:       0
# Processing file [149/7500]
#   Features:       0
# Processing file [150/7500]
#   Features:       0
# Processing file [151/7500]
#   Features:       0
# Processing file [152/7500]
#   Features:       0
# Processing file [153/7500]
#   Features:       0
# Processing file [154/7500]
#   Features:       0
# Processing file [155/7500]
#   Features:       0
# Processing file [156/7500]
#   Features:       0
# Processing file [157/7500]
#   Features:       0
# Processing file [158/7500]
#   Features:       0
# Processing file [159/7500]
#   Features:       0
# Processing file [160/7500]
#   Features:       0
# Processing file [161/7500]
#   Features:       0
# Processing file [162/7500]
#   Features:       0
# Processing file [163/7500]
#   Features:       0
# Processing file [164/7500]
#   Features:       0
# Processing file [165/7500]
#   Features:       0
# Processing file [166/7500]
#   Features:       0
# Processing file [167/7500]
#   Features:       0
# Processing file [168/7500]
#   Features:       0
# Processing file [169/7500]
#   Features:       0
# Processing file [170/7500]
#   Features:       0
# Processing file [171/7500]
#   Features:       0
# Processing file [172/7500]
#   Features:       0
# Processing file [173/7500]
#   Features:       0
# Processing file [174/7500]
#   Features:       0
# Processing file [175/7500]
#   Features:       0
# Processing file [176/7500]
#   Features:       0
# Processing file [177/7500]
#   Features:       0
# Processing file [178/7500]
#   Features:       0
# Processing file [179/7500]
#   Features:       0
# Processing file [180/7500]
#   Features:       0
# Processing file [181/7500]
#   Features:       0
# Processing file [182/7500]
#   Features:       0
# Processing file [183/7500]
#   Features:       0
# Processing file [184/7500]
#   Features:       0
# Processing file [185/7500]
#   Features:       0
# Processing file [186/7500]
#   Features:       0
# Processing file [187/7500]
#   Features:       0
# Processing file [188/7500]
#   Features:       0
# Processing file [189/7500]
#   Features:       0
# Processing file [190/7500]
#   Features:       0
# Processing file [191/7500]
#   Features:       0
# Processing file [192/7500]
#   Features:       0
# Processing file [193/7500]
#   Features:       0
# Processing file [194/7500]
#   Features:       0
# Processing file [195/7500]
#   Features:       0
# Processing file [196/7500]
#   Features:       0
# Processing file [197/7500]
#   Features:       0
# Processing file [198/7500]
#   Features:       0
# Processing file [199/7500]
#   Features:       0
# Processing file [200/7500]
#   Features:       0
# Processing file [201/7500]
#   Features:       0
# Processing file [202/7500]
#   Features:       0
# Processing file [203/7500]
#   Features:       0
# Processing file [204/7500]
#   Features:       0
# Processing file [205/7500]
#   Features:       0
# Processing file [206/7500]
#   Features:       0
# Processing file [207/7500]
#   Features:       0
# Processing file [208/7500]
#   Features:       0
# Processing file [209/7500]
#   Features:       0
# Processing file [210/7500]
#   Features:       0
# Processing file [211/7500]
#   Features:       0
# Processing file [212/7500]
#   Features:       0
# Processing file [213/7500]
#   Features:       0
# Processing file [214/7500]
#   Features:       0
# Processing file [215/7500]
#   Features:       0
# Processing file [216/7500]
#   Features:       0
# Processing file [217/7500]
#   Features:       0
# Processing file [218/7500]
#   Features:       0
# Processing file [219/7500]
#   Features:       0
# Processing file [220/7500]
#   Features:       0
# Processing file [221/7500]
#   Features:       0
# Processing file [222/7500]
#   Features:       0
# Processing file [223/7500]
#   Features:       0
# Processing file [224/7500]
#   Features:       0
# Processing file [225/7500]
#   Features:       0
# Processing file [226/7500]
#   Features:       0
# Processing file [227/7500]
#   Features:       0
# Processing file [228/7500]
#   Features:       0
# Processing file [229/7500]
#   Features:       0
# Processing file [230/7500]
#   Features:       0
# Processing file [231/7500]
#   Features:       0
# Processing file [232/7500]
#   Features:       0
# Processing file [233/7500]
#   Features:       0
# Processing file [234/7500]
#   Features:       0
# Processing file [235/7500]
#   Features:       0
# Processing file [236/7500]
#   Features:       0
# Processing file [237/7500]
#   Features:       0
# Processing file [238/7500]
#   Features:       0
# Processing file [239/7500]
#   Features:       0
# Processing file [240/7500]
#   Features:       0
# Processing file [241/7500]
#   Features:       0
# Processing file [242/7500]
#   Features:       0
# Processing file [243/7500]
#   Features:       0
# Processing file [244/7500]
#   Features:       0
# Processing file [245/7500]
#   Features:       0
# Processing file [246/7500]
#   Features:       0
# Processing file [247/7500]
#   Features:       0
# Processing file [248/7500]
#   Features:       0
# Processing file [249/7500]
#   Features:       0
# Processing file [250/7500]
#   Features:       0
# Processing file [251/7500]
#   Features:       0
# Processing file [252/7500]
#   Features:       0
# Processing file [253/7500]
#   Features:       0
# Processing file [254/7500]
#   Features:       0
# Processing file [255/7500]
#   Features:       0
# Processing file [256/7500]
#   Features:       0
# Processing file [257/7500]
#   Features:       0
# Processing file [258/7500]
#   Features:       0
# Processing file [259/7500]
#   Features:       0
# Processing file [260/7500]
#   Features:       0
# Processing file [261/7500]
#   Features:       0
# Processing file [262/7500]
#   Features:       0
# Processing file [263/7500]
#   Features:       0
# Processing file [264/7500]
#   Features:       0
# Processing file [265/7500]
#   Features:       0
# Processing file [266/7500]
#   Features:       0
# Processing file [267/7500]
#   Features:       0
# Processing file [268/7500]
#   Features:       0
# Processing file [269/7500]
#   Features:       0
# Processing file [270/7500]
#   Features:       0
# Processing file [271/7500]
#   Features:       0
# Processing file [272/7500]
#   Features:       0
# Processing file [273/7500]
#   Features:       0
# Processing file [274/7500]
#   Features:       0
# Processing file [275/7500]
#   Features:       0
# Processing file [276/7500]
#   Features:       0
# Processing file [277/7500]
#   Features:       0
# Processing file [278/7500]
#   Features:       0
# Processing file [279/7500]
#   Features:       0
# Processing file [280/7500]
#   Features:       0
# Processing file [281/7500]
#   Features:       0
# Processing file [282/7500]
#   Features:       0
# Processing file [283/7500]
#   Features:       0
# Processing file [284/7500]
#   Features:       0
# Processing file [285/7500]
#   Features:       0
# Processing file [286/7500]
#   Features:       0
# Processing file [287/7500]
#   Features:       0
# Processing file [288/7500]
#   Features:       0
# Processing file [289/7500]
#   Features:       0
# Processing file [290/7500]
#   Features:       0
# Processing file [291/7500]
#   Features:       0
# Processing file [292/7500]
#   Features:       0
# Processing file [293/7500]
#   Features:       0
# Processing file [294/7500]
#   Features:       0
# Processing file [295/7500]
#   Features:       0
# Processing file [296/7500]
#   Features:       0
# Processing file [297/7500]
#   Features:       0
# Processing file [298/7500]
#   Features:       0
# Processing file [299/7500]
#   Features:       0
# Processing file [300/7500]
#   Features:       0
# Processing file [301/7500]
#   Features:       0
# Processing file [302/7500]
#   Features:       0
# Processing file [303/7500]
#   Features:       0
# Processing file [304/7500]
#   Features:       0
# Processing file [305/7500]
#   Features:       0
# Processing file [306/7500]
#   Features:       0
# Processing file [307/7500]
#   Features:       0
# Processing file [308/7500]
#   Features:       0
# Processing file [309/7500]
#   Features:       0
# Processing file [310/7500]
#   Features:       0
# Processing file [311/7500]
#   Features:       0
# Processing file [312/7500]
#   Features:       0
# Processing file [313/7500]
#   Features:       0
# Processing file [314/7500]
#   Features:       0
# Processing file [315/7500]
#   Features:       0
# Processing file [316/7500]
#   Features:       0
# Processing file [317/7500]
#   Features:       0
# Processing file [318/7500]
#   Features:       0
# Processing file [319/7500]
#   Features:       0
# Processing file [320/7500]
#   Features:       0
# Processing file [321/7500]
#   Features:       0
# Processing file [322/7500]
#   Features:       0
# Processing file [323/7500]
#   Features:       0
# Processing file [324/7500]
#   Features:       0
# Processing file [325/7500]
#   Features:       0
# Processing file [326/7500]
#   Features:       0
# Processing file [327/7500]
#   Features:       0
# Processing file [328/7500]
#   Features:       0
# Processing file [329/7500]
#   Features:       0
# Processing file [330/7500]
#   Features:       0
# Processing file [331/7500]
#   Features:       0
# Processing file [332/7500]
#   Features:       0
# Processing file [333/7500]
#   Features:       0
# Processing file [334/7500]
#   Features:       0
# Processing file [335/7500]
#   Features:       0
# Processing file [336/7500]
#   Features:       0
# Processing file [337/7500]
#   Features:       0
# Processing file [338/7500]
#   Features:       0
# Processing file [339/7500]
#   Features:       0
# Processing file [340/7500]
#   Features:       0
# Processing file [341/7500]
#   Features:       0
# Processing file [342/7500]
#   Features:       0
# Processing file [343/7500]
#   Features:       0
# Processing file [344/7500]
#   Features:       0
# Processing file [345/7500]
#   Features:       0
# Processing file [346/7500]
#   Features:       0
# Processing file [347/7500]
#   Features:       0
# Processing file [348/7500]
#   Features:       0
# Processing file [349/7500]
#   Features:       0
# Processing file [350/7500]
#   Features:       0
# Processing file [351/7500]
#   Features:       0
# Processing file [352/7500]
#   Features:       0
# Processing file [353/7500]
#   Features:       0
# Processing file [354/7500]
#   Features:       0
# Processing file [355/7500]
#   Features:       0
# Processing file [356/7500]
#   Features:       0
# Processing file [357/7500]
#   Features:       0
# Processing file [358/7500]
#   Features:       0
# Processing file [359/7500]
#   Features:       0
# Processing file [360/7500]
#   Features:       0
# Processing file [361/7500]
#   Features:       0
# Processing file [362/7500]
#   Features:       0
# Processing file [363/7500]
#   Features:       0
# Processing file [364/7500]
#   Features:       0
# Processing file [365/7500]
#   Features:       0
# Processing file [366/7500]
#   Features:       0
# Processing file [367/7500]
#   Features:       0
# Processing file [368/7500]
#   Features:       0
# Processing file [369/7500]
#   Features:       0
# Processing file [370/7500]
#   Features:       0
# Processing file [371/7500]
#   Features:       0
# Processing file [372/7500]
#   Features:       0
# Processing file [373/7500]
#   Features:       0
# Processing file [374/7500]
#   Features:       0
# Processing file [375/7500]
#   Features:       0
# Processing file [376/7500]
#   Features:       0
# Processing file [377/7500]
#   Features:       0
# Processing file [378/7500]
#   Features:       0
# Processing file [379/7500]
#   Features:       0
# Processing file [380/7500]
#   Features:       0
# Processing file [381/7500]
#   Features:       0
# Processing file [382/7500]
#   Features:       0
# Processing file [383/7500]
#   Features:       0
# Processing file [384/7500]
#   Features:       0
# Processing file [385/7500]
#   Features:       0
# Processing file [386/7500]
#   Features:       0
# Processing file [387/7500]
#   Features:       0
# Processing file [388/7500]
#   Features:       0
# Processing file [389/7500]
#   Features:       0
# Processing file [390/7500]
#   Features:       0
# Processing file [391/7500]
#   Features:       0
# Processing file [392/7500]
#   Features:       0
# Processing file [393/7500]
#   Features:       0
# Processing file [394/7500]
#   Features:       0
# Processing file [395/7500]
#   Features:       0
# Processing file [396/7500]
#   Features:       0
# Processing file [397/7500]
#   Features:       0
# Processing file [398/7500]
#   Features:       0
# Processing file [399/7500]
#   Features:       0
# Processing file [400/7500]
#   Features:       0
# Processing file [401/7500]
#   Features:       0
# Processing file [402/7500]
#   Features:       0
# Processing file [403/7500]
#   Features:       0
# Processing file [404/7500]
#   Features:       0
# Processing file [405/7500]
#   Features:       0
# Processing file [406/7500]
#   Features:       0
# Processing file [407/7500]
#   Features:       0
# Processing file [408/7500]
#   Features:       0
# Processing file [409/7500]
#   Features:       0
# Processing file [410/7500]
#   Features:       0
# Processing file [411/7500]
#   Features:       0
# Processing file [412/7500]
#   Features:       0
# Processing file [413/7500]
#   Features:       0
# Processing file [414/7500]
#   Features:       0
# Processing file [415/7500]
#   Features:       0
# Processing file [416/7500]
#   Features:       0
# Processing file [417/7500]
#   Features:       0
# Processing file [418/7500]
#   Features:       0
# Processing file [419/7500]
#   Features:       0
# Processing file [420/7500]
#   Features:       0
# Processing file [421/7500]
#   Features:       0
# Processing file [422/7500]
#   Features:       0
# Processing file [423/7500]
#   Features:       0
# Processing file [424/7500]
#   Features:       0
# Processing file [425/7500]
#   Features:       0
# Processing file [426/7500]
#   Features:       0
# Processing file [427/7500]
#   Features:       0
# Processing file [428/7500]
#   Features:       0
# Processing file [429/7500]
#   Features:       0
# Processing file [430/7500]
#   Features:       0
# Processing file [431/7500]
#   Features:       0
# Processing file [432/7500]
#   Features:       0
# Processing file [433/7500]
#   Features:       0
# Processing file [434/7500]
#   Features:       0
# Processing file [435/7500]
#   Features:       0
# Processing file [436/7500]
#   Features:       0
# Processing file [437/7500]
#   Features:       0
# Processing file [438/7500]
#   Features:       0
# Processing file [439/7500]
#   Features:       0
# Processing file [440/7500]
#   Features:       0
# Processing file [441/7500]
#   Features:       0
# Processing file [442/7500]
#   Features:       0
# Processing file [443/7500]
#   Features:       0
# Processing file [444/7500]
#   Features:       0
# Processing file [445/7500]
#   Features:       0
# Processing file [446/7500]
#   Features:       0
# Processing file [447/7500]
#   Features:       0
# Processing file [448/7500]
#   Features:       0
# Processing file [449/7500]
#   Features:       0
# Processing file [450/7500]
#   Features:       0
# Processing file [451/7500]
#   Features:       0
# Processing file [452/7500]
#   Features:       0
# Processing file [453/7500]
#   Features:       0
# Processing file [454/7500]
#   Features:       0
# Processing file [455/7500]
#   Features:       0
# Processing file [456/7500]
#   Features:       0
# Processing file [457/7500]
#   Features:       0
# Processing file [458/7500]
#   Features:       0
# Processing file [459/7500]
#   Features:       0
# Processing file [460/7500]
#   Features:       0
# Processing file [461/7500]
#   Features:       0
# Processing file [462/7500]
#   Features:       0
# Processing file [463/7500]
#   Features:       0
# Processing file [464/7500]
#   Features:       0
# Processing file [465/7500]
#   Features:       0
# Processing file [466/7500]
#   Features:       0
# Processing file [467/7500]
#   Features:       0
# Processing file [468/7500]
#   Features:       0
# Processing file [469/7500]
#   Features:       0
# Processing file [470/7500]
#   Features:       0
# Processing file [471/7500]
#   Features:       0
# Processing file [472/7500]
#   Features:       0
# Processing file [473/7500]
#   Features:       0
# Processing file [474/7500]
#   Features:       0
# Processing file [475/7500]
#   Features:       0
# Processing file [476/7500]
#   Features:       0
# Processing file [477/7500]
#   Features:       0
# Processing file [478/7500]
#   Features:       0
# Processing file [479/7500]
#   Features:       0
# Processing file [480/7500]
#   Features:       0
# Processing file [481/7500]
#   Features:       0
# Processing file [482/7500]
#   Features:       0
# Processing file [483/7500]
#   Features:       0
# Processing file [484/7500]
#   Features:       0
# Processing file [485/7500]
#   Features:       0
# Processing file [486/7500]
#   Features:       0
# Processing file [487/7500]
#   Features:       0
# Processing file [488/7500]
#   Features:       0
# Processing file [489/7500]
#   Features:       0
# Processing file [490/7500]
#   Features:       0
# Processing file [491/7500]
#   Features:       0
# Processing file [492/7500]
#   Features:       0
# Processing file [493/7500]
#   Features:       0
# Processing file [494/7500]
#   Features:       0
# Processing file [495/7500]
#   Features:       0
# Processing file [496/7500]
#   Features:       0
# Processing file [497/7500]
#   Features:       0
# Processing file [498/7500]
#   Features:       0
# Processing file [499/7500]
#   Features:       0
# Processing file [500/7500]
#   Features:       0
# Processing file [501/7500]
#   Features:       0
# Processing file [502/7500]
#   Features:       0
# Processing file [503/7500]
#   Features:       0
# Processing file [504/7500]
#   Features:       0
# Processing file [505/7500]
#   Features:       0
# Processing file [506/7500]
#   Features:       0
# Processing file [507/7500]
#   Features:       0
# Processing file [508/7500]
#   Features:       0
# Processing file [509/7500]
#   Features:       0
# Processing file [510/7500]
#   Features:       0
# Processing file [511/7500]
#   Features:       0
# Processing file [512/7500]
#   Features:       0
# Processing file [513/7500]
#   Features:       0
# Processing file [514/7500]
#   Features:       0
# Processing file [515/7500]
#   Features:       0
# Processing file [516/7500]
#   Features:       0
# Processing file [517/7500]
#   Features:       0
# Processing file [518/7500]
#   Features:       0
# Processing file [519/7500]
#   Features:       0
# Processing file [520/7500]
#   Features:       0
# Processing file [521/7500]
#   Features:       0
# Processing file [522/7500]
#   Features:       0
# Processing file [523/7500]
#   Features:       0
# Processing file [524/7500]
#   Features:       0
# Processing file [525/7500]
#   Features:       0
# Processing file [526/7500]
#   Features:       0
# Processing file [527/7500]
#   Features:       0
# Processing file [528/7500]
#   Features:       0
# Processing file [529/7500]
#   Features:       0
# Processing file [530/7500]
#   Features:       0
# Processing file [531/7500]
#   Features:       0
# Processing file [532/7500]
#   Features:       0
# Processing file [533/7500]
#   Features:       0
# Processing file [534/7500]
#   Features:       0
# Processing file [535/7500]
#   Features:       0
# Processing file [536/7500]
#   Features:       0
# Processing file [537/7500]
#   Features:       0
# Processing file [538/7500]
#   Features:       0
# Processing file [539/7500]
#   Features:       0
# Processing file [540/7500]
#   Features:       0
# Processing file [541/7500]
#   Features:       0
# Processing file [542/7500]
#   Features:       0
# Processing file [543/7500]
#   Features:       0
# Processing file [544/7500]
#   Features:       0
# Processing file [545/7500]
#   Features:       0
# Processing file [546/7500]
#   Features:       0
# Processing file [547/7500]
#   Features:       0
# Processing file [548/7500]
#   Features:       0
# Processing file [549/7500]
#   Features:       0
# Processing file [550/7500]
#   Features:       0
# Processing file [551/7500]
#   Features:       0
# Processing file [552/7500]
#   Features:       0
# Processing file [553/7500]
#   Features:       0
# Processing file [554/7500]
#   Features:       0
# Processing file [555/7500]
#   Features:       0
# Processing file [556/7500]
#   Features:       0
# Processing file [557/7500]
#   Features:       0
# Processing file [558/7500]
#   Features:       0
# Processing file [559/7500]
#   Features:       0
# Processing file [560/7500]
#   Features:       0
# Processing file [561/7500]
#   Features:       0
# Processing file [562/7500]
#   Features:       0
# Processing file [563/7500]
#   Features:       0
# Processing file [564/7500]
#   Features:       0
# Processing file [565/7500]
#   Features:       0
# Processing file [566/7500]
#   Features:       0
# Processing file [567/7500]
#   Features:       0
# Processing file [568/7500]
#   Features:       0
# Processing file [569/7500]
#   Features:       0
# Processing file [570/7500]
#   Features:       0
# Processing file [571/7500]
#   Features:       0
# Processing file [572/7500]
#   Features:       0
# Processing file [573/7500]
#   Features:       0
# Processing file [574/7500]
#   Features:       0
# Processing file [575/7500]
#   Features:       0
# Processing file [576/7500]
#   Features:       0
# Processing file [577/7500]
#   Features:       0
# Processing file [578/7500]
#   Features:       0
# Processing file [579/7500]
#   Features:       0
# Processing file [580/7500]
#   Features:       0
# Processing file [581/7500]
#   Features:       0
# Processing file [582/7500]
#   Features:       0
# Processing file [583/7500]
#   Features:       0
# Processing file [584/7500]
#   Features:       0
# Processing file [585/7500]
#   Features:       0
# Processing file [586/7500]
#   Features:       0
# Processing file [587/7500]
#   Features:       0
# Processing file [588/7500]
#   Features:       0
# Processing file [589/7500]
#   Features:       0
# Processing file [590/7500]
#   Features:       0
# Processing file [591/7500]
#   Features:       0
# Processing file [592/7500]
#   Features:       0
# Processing file [593/7500]
#   Features:       0
# Processing file [594/7500]
#   Features:       0
# Processing file [595/7500]
#   Features:       0
# Processing file [596/7500]
#   Features:       0
# Processing file [597/7500]
#   Features:       0
# Processing file [598/7500]
#   Features:       0
# Processing file [599/7500]
#   Features:       0
# Processing file [600/7500]
#   Features:       0
# Processing file [601/7500]
#   Features:       0
# Processing file [602/7500]
#   Features:       0
# Processing file [603/7500]
#   Features:       0
# Processing file [604/7500]
#   Features:       0
# Processing file [605/7500]
#   Features:       0
# Processing file [606/7500]
#   Features:       0
# Processing file [607/7500]
#   Features:       0
# Processing file [608/7500]
#   Features:       0
# Processing file [609/7500]
#   Features:       0
# Processing file [610/7500]
#   Features:       0
# Processing file [611/7500]
#   Features:       0
# Processing file [612/7500]
#   Features:       0
# Processing file [613/7500]
#   Features:       0
# Processing file [614/7500]
#   Features:       0
# Processing file [615/7500]
#   Features:       0
# Processing file [616/7500]
#   Features:       0
# Processing file [617/7500]
#   Features:       0
# Processing file [618/7500]
#   Features:       0
# Processing file [619/7500]
#   Features:       0
# Processing file [620/7500]
#   Features:       0
# Processing file [621/7500]
#   Features:       0
# Processing file [622/7500]
#   Features:       0
# Processing file [623/7500]
#   Features:       0
# Processing file [624/7500]
#   Features:       0
# Processing file [625/7500]
#   Features:       0
# Processing file [626/7500]
#   Features:       0
# Processing file [627/7500]
#   Features:       0
# Processing file [628/7500]
#   Features:       0
# Processing file [629/7500]
#   Features:       0
# Processing file [630/7500]
#   Features:       0
# Processing file [631/7500]
#   Features:       0
# Processing file [632/7500]
#   Features:       0
# Processing file [633/7500]
#   Features:       0
# Processing file [634/7500]
#   Features:       0
# Processing file [635/7500]
#   Features:       0
# Processing file [636/7500]
#   Features:       0
# Processing file [637/7500]
#   Features:       0
# Processing file [638/7500]
#   Features:       0
# Processing file [639/7500]
#   Features:       0
# Processing file [640/7500]
#   Features:       0
# Processing file [641/7500]
#   Features:       0
# Processing file [642/7500]
#   Features:       0
# Processing file [643/7500]
#   Features:       0
# Processing file [644/7500]
#   Features:       0
# Processing file [645/7500]
#   Features:       0
# Processing file [646/7500]
#   Features:       0
# Processing file [647/7500]
#   Features:       0
# Processing file [648/7500]
#   Features:       0
# Processing file [649/7500]
#   Features:       0
# Processing file [650/7500]
#   Features:       0
# Processing file [651/7500]
#   Features:       0
# Processing file [652/7500]
#   Features:       0
# Processing file [653/7500]
#   Features:       0
# Processing file [654/7500]
#   Features:       0
# Processing file [655/7500]
#   Features:       0
# Processing file [656/7500]
#   Features:       0
# Processing file [657/7500]
#   Features:       0
# Processing file [658/7500]
#   Features:       0
# Processing file [659/7500]
#   Features:       0
# Processing file [660/7500]
#   Features:       0
# Processing file [661/7500]
#   Features:       0
# Processing file [662/7500]
#   Features:       0
# Processing file [663/7500]
#   Features:       0
# Processing file [664/7500]
#   Features:       0
# Processing file [665/7500]
#   Features:       0
# Processing file [666/7500]
#   Features:       0
# Processing file [667/7500]
#   Features:       0
# Processing file [668/7500]
#   Features:       0
# Processing file [669/7500]
#   Features:       0
# Processing file [670/7500]
#   Features:       0
# Processing file [671/7500]
#   Features:       0
# Processing file [672/7500]
#   Features:       0
# Processing file [673/7500]
#   Features:       0
# Processing file [674/7500]
#   Features:       0
# Processing file [675/7500]
#   Features:       0
# Processing file [676/7500]
#   Features:       0
# Processing file [677/7500]
#   Features:       0
# Processing file [678/7500]
#   Features:       0
# Processing file [679/7500]
#   Features:       0
# Processing file [680/7500]
#   Features:       0
# Processing file [681/7500]
#   Features:       0
# Processing file [682/7500]
#   Features:       0
# Processing file [683/7500]
#   Features:       0
# Processing file [684/7500]
#   Features:       0
# Processing file [685/7500]
#   Features:       0
# Processing file [686/7500]
#   Features:       0
# Processing file [687/7500]
#   Features:       0
# Processing file [688/7500]
#   Features:       0
# Processing file [689/7500]
#   Features:       0
# Processing file [690/7500]
#   Features:       0
# Processing file [691/7500]
#   Features:       0
# Processing file [692/7500]
#   Features:       0
# Processing file [693/7500]
#   Features:       0
# Processing file [694/7500]
#   Features:       0
# Processing file [695/7500]
#   Features:       0
# Processing file [696/7500]
#   Features:       0
# Processing file [697/7500]
#   Features:       0
# Processing file [698/7500]
#   Features:       0
# Processing file [699/7500]
#   Features:       0
# Processing file [700/7500]
#   Features:       0
# Processing file [701/7500]
#   Features:       0
# Processing file [702/7500]
#   Features:       0
# Processing file [703/7500]
#   Features:       0
# Processing file [704/7500]
#   Features:       0
# Processing file [705/7500]
#   Features:       0
# Processing file [706/7500]
#   Features:       0
# Processing file [707/7500]
#   Features:       0
# Processing file [708/7500]
#   Features:       0
# Processing file [709/7500]
#   Features:       0
# Processing file [710/7500]
#   Features:       0
# Processing file [711/7500]
#   Features:       0
# Processing file [712/7500]
#   Features:       0
# Processing file [713/7500]
#   Features:       0
# Processing file [714/7500]
#   Features:       0
# Processing file [715/7500]
#   Features:       0
# Processing file [716/7500]
#   Features:       0
# Processing file [717/7500]
#   Features:       0
# Processing file [718/7500]
#   Features:       0
# Processing file [719/7500]
#   Features:       0
# Processing file [720/7500]
#   Features:       0
# Processing file [721/7500]
#   Features:       0
# Processing file [722/7500]
#   Features:       0
# Processing file [723/7500]
#   Features:       0
# Processing file [724/7500]
#   Features:       0
# Processing file [725/7500]
#   Features:       0
# Processing file [726/7500]
#   Features:       0
# Processing file [727/7500]
#   Features:       0
# Processing file [728/7500]
#   Features:       0
# Processing file [729/7500]
#   Features:       0
# Processing file [730/7500]
#   Features:       0
# Processing file [731/7500]
#   Features:       0
# Processing file [732/7500]
#   Features:       0
# Processing file [733/7500]
#   Features:       0
# Processing file [734/7500]
#   Features:       0
# Processing file [735/7500]
#   Features:       0
# Processing file [736/7500]
#   Features:       0
# Processing file [737/7500]
#   Features:       0
# Processing file [738/7500]
#   Features:       0
# Processing file [739/7500]
#   Features:       0
# Processing file [740/7500]
#   Features:       0
# Processing file [741/7500]
#   Features:       0
# Processing file [742/7500]
#   Features:       0
# Processing file [743/7500]
#   Features:       0
# Processing file [744/7500]
#   Features:       0
# Processing file [745/7500]
#   Features:       0
# Processing file [746/7500]
#   Features:       0
# Processing file [747/7500]
#   Features:       0
# Processing file [748/7500]
#   Features:       0
# Processing file [749/7500]
#   Features:       0
# Processing file [750/7500]
#   Features:       0
# Processing file [751/7500]
#   Features:       0
# Processing file [752/7500]
#   Features:       0
# Processing file [753/7500]
#   Features:       0
# Processing file [754/7500]
#   Features:       0
# Processing file [755/7500]
#   Features:       0
# Processing file [756/7500]
#   Features:       0
# Processing file [757/7500]
#   Features:       0
# Processing file [758/7500]
#   Features:       0
# Processing file [759/7500]
#   Features:       0
# Processing file [760/7500]
#   Features:       0
# Processing file [761/7500]
#   Features:       0
# Processing file [762/7500]
#   Features:       0
# Processing file [763/7500]
#   Features:       0
# Processing file [764/7500]
#   Features:       0
# Processing file [765/7500]
#   Features:       0
# Processing file [766/7500]
#   Features:       0
# Processing file [767/7500]
#   Features:       0
# Processing file [768/7500]
#   Features:       0
# Processing file [769/7500]
#   Features:       0
# Processing file [770/7500]
#   Features:       0
# Processing file [771/7500]
#   Features:       0
# Processing file [772/7500]
#   Features:       0
# Processing file [773/7500]
#   Features:       0
# Processing file [774/7500]
#   Features:       0
# Processing file [775/7500]
#   Features:       0
# Processing file [776/7500]
#   Features:       0
# Processing file [777/7500]
#   Features:       0
# Processing file [778/7500]
#   Features:       0
# Processing file [779/7500]
#   Features:       0
# Processing file [780/7500]
#   Features:       0
# Processing file [781/7500]
#   Features:       0
# Processing file [782/7500]
#   Features:       0
# Processing file [783/7500]
#   Features:       0
# Processing file [784/7500]
#   Features:       0
# Processing file [785/7500]
#   Features:       0
# Processing file [786/7500]
#   Features:       0
# Processing file [787/7500]
#   Features:       0
# Processing file [788/7500]
#   Features:       0
# Processing file [789/7500]
#   Features:       0
# Processing file [790/7500]
#   Features:       0
# Processing file [791/7500]
#   Features:       0
# Processing file [792/7500]
#   Features:       0
# Processing file [793/7500]
#   Features:       0
# Processing file [794/7500]
#   Features:       0
# Processing file [795/7500]
#   Features:       0
# Processing file [796/7500]
#   Features:       0
# Processing file [797/7500]
#   Features:       0
# Processing file [798/7500]
#   Features:       0
# Processing file [799/7500]
#   Features:       0
# Processing file [800/7500]
#   Features:       0
# Processing file [801/7500]
#   Features:       0
# Processing file [802/7500]
#   Features:       0
# Processing file [803/7500]
#   Features:       0
# Processing file [804/7500]
#   Features:       0
# Processing file [805/7500]
#   Features:       0
# Processing file [806/7500]
#   Features:       0
# Processing file [807/7500]
#   Features:       0
# Processing file [808/7500]
#   Features:       0
# Processing file [809/7500]
#   Features:       0
# Processing file [810/7500]
#   Features:       0
# Processing file [811/7500]
#   Features:       0
# Processing file [812/7500]
#   Features:       0
# Processing file [813/7500]
#   Features:       0
# Processing file [814/7500]
#   Features:       0
# Processing file [815/7500]
#   Features:       0
# Processing file [816/7500]
#   Features:       0
# Processing file [817/7500]
#   Features:       0
# Processing file [818/7500]
#   Features:       0
# Processing file [819/7500]
#   Features:       0
# Processing file [820/7500]
#   Features:       0
# Processing file [821/7500]
#   Features:       0
# Processing file [822/7500]
#   Features:       0
# Processing file [823/7500]
#   Features:       0
# Processing file [824/7500]
#   Features:       0
# Processing file [825/7500]
#   Features:       0
# Processing file [826/7500]
#   Features:       0
# Processing file [827/7500]
#   Features:       0
# Processing file [828/7500]
#   Features:       0
# Processing file [829/7500]
#   Features:       0
# Processing file [830/7500]
#   Features:       0
# Processing file [831/7500]
#   Features:       0
# Processing file [832/7500]
#   Features:       0
# Processing file [833/7500]
#   Features:       0
# Processing file [834/7500]
#   Features:       0
# Processing file [835/7500]
#   Features:       0
# Processing file [836/7500]
#   Features:       0
# Processing file [837/7500]
#   Features:       0
# Processing file [838/7500]
#   Features:       0
# Processing file [839/7500]
#   Features:       0
# Processing file [840/7500]
#   Features:       0
# Processing file [841/7500]
#   Features:       0
# Processing file [842/7500]
#   Features:       0
# Processing file [843/7500]
#   Features:       0
# Processing file [844/7500]
#   Features:       0
# Processing file [845/7500]
#   Features:       0
# Processing file [846/7500]
#   Features:       0
# Processing file [847/7500]
#   Features:       0
# Processing file [848/7500]
#   Features:       0
# Processing file [849/7500]
#   Features:       0
# Processing file [850/7500]
#   Features:       0
# Processing file [851/7500]
#   Features:       0
# Processing file [852/7500]
#   Features:       0
# Processing file [853/7500]
#   Features:       0
# Processing file [854/7500]
#   Features:       0
# Processing file [855/7500]
#   Features:       0
# Processing file [856/7500]
#   Features:       0
# Processing file [857/7500]
#   Features:       0
# Processing file [858/7500]
#   Features:       0
# Processing file [859/7500]
#   Features:       0
# Processing file [860/7500]
#   Features:       0
# Processing file [861/7500]
#   Features:       0
# Processing file [862/7500]
#   Features:       0
# Processing file [863/7500]
#   Features:       0
# Processing file [864/7500]
#   Features:       0
# Processing file [865/7500]
#   Features:       0
# Processing file [866/7500]
#   Features:       0
# Processing file [867/7500]
#   Features:       0
# Processing file [868/7500]
#   Features:       0
# Processing file [869/7500]
#   Features:       0
# Processing file [870/7500]
#   Features:       0
# Processing file [871/7500]
#   Features:       0
# Processing file [872/7500]
#   Features:       0
# Processing file [873/7500]
#   Features:       0
# Processing file [874/7500]
#   Features:       0
# Processing file [875/7500]
#   Features:       0
# Processing file [876/7500]
#   Features:       0
# Processing file [877/7500]
#   Features:       0
# Processing file [878/7500]
#   Features:       0
# Processing file [879/7500]
#   Features:       0
# Processing file [880/7500]
#   Features:       0
# Processing file [881/7500]
#   Features:       0
# Processing file [882/7500]
#   Features:       0
# Processing file [883/7500]
#   Features:       0
# Processing file [884/7500]
#   Features:       0
# Processing file [885/7500]
#   Features:       0
# Processing file [886/7500]
#   Features:       0
# Processing file [887/7500]
#   Features:       0
# Processing file [888/7500]
#   Features:       0
# Processing file [889/7500]
#   Features:       0
# Processing file [890/7500]
#   Features:       0
# Processing file [891/7500]
#   Features:       0
# Processing file [892/7500]
#   Features:       0
# Processing file [893/7500]
#   Features:       0
# Processing file [894/7500]
#   Features:       0
# Processing file [895/7500]
#   Features:       0
# Processing file [896/7500]
#   Features:       0
# Processing file [897/7500]
#   Features:       0
# Processing file [898/7500]
#   Features:       0
# Processing file [899/7500]
#   Features:       0
# Processing file [900/7500]
#   Features:       0
# Processing file [901/7500]
#   Features:       0
# Processing file [902/7500]
#   Features:       0
# Processing file [903/7500]
#   Features:       0
# Processing file [904/7500]
#   Features:       0
# Processing file [905/7500]
#   Features:       0
# Processing file [906/7500]
#   Features:       0
# Processing file [907/7500]
#   Features:       0
# Processing file [908/7500]
#   Features:       0
# Processing file [909/7500]
#   Features:       0
# Processing file [910/7500]
#   Features:       0
# Processing file [911/7500]
#   Features:       0
# Processing file [912/7500]
#   Features:       0
# Processing file [913/7500]
#   Features:       0
# Processing file [914/7500]
#   Features:       0
# Processing file [915/7500]
#   Features:       0
# Processing file [916/7500]
#   Features:       0
# Processing file [917/7500]
#   Features:       0
# Processing file [918/7500]
#   Features:       0
# Processing file [919/7500]
#   Features:       0
# Processing file [920/7500]
#   Features:       0
# Processing file [921/7500]
#   Features:       0
# Processing file [922/7500]
#   Features:       0
# Processing file [923/7500]
#   Features:       0
# Processing file [924/7500]
#   Features:       0
# Processing file [925/7500]
#   Features:       0
# Processing file [926/7500]
#   Features:       0
# Processing file [927/7500]
#   Features:       0
# Processing file [928/7500]
#   Features:       0
# Processing file [929/7500]
#   Features:       0
# Processing file [930/7500]
#   Features:       0
# Processing file [931/7500]
#   Features:       0
# Processing file [932/7500]
#   Features:       0
# Processing file [933/7500]
#   Features:       0
# Processing file [934/7500]
#   Features:       0
# Processing file [935/7500]
#   Features:       0
# Processing file [936/7500]
#   Features:       0
# Processing file [937/7500]
#   Features:       0
# Processing file [938/7500]
#   Features:       0
# Processing file [939/7500]
#   Features:       0
# Processing file [940/7500]
#   Features:       0
# Processing file [941/7500]
#   Features:       0
# Processing file [942/7500]
#   Features:       0
# Processing file [943/7500]
#   Features:       0
# Processing file [944/7500]
#   Features:       0
# Processing file [945/7500]
#   Features:       0
# Processing file [946/7500]
#   Features:       0
# Processing file [947/7500]
#   Features:       0
# Processing file [948/7500]
#   Features:       0
# Processing file [949/7500]
#   Features:       0
# Processing file [950/7500]
#   Features:       0
# Processing file [951/7500]
#   Features:       0
# Processing file [952/7500]
#   Features:       0
# Processing file [953/7500]
#   Features:       0
# Processing file [954/7500]
#   Features:       0
# Processing file [955/7500]
#   Features:       0
# Processing file [956/7500]
#   Features:       0
# Processing file [957/7500]
#   Features:       0
# Processing file [958/7500]
#   Features:       0
# Processing file [959/7500]
#   Features:       0
# Processing file [960/7500]
#   Features:       0
# Processing file [961/7500]
#   Features:       0
# Processing file [962/7500]
#   Features:       0
# Processing file [963/7500]
#   Features:       0
# Processing file [964/7500]
#   Features:       0
# Processing file [965/7500]
#   Features:       0
# Processing file [966/7500]
#   Features:       0
# Processing file [967/7500]
#   Features:       0
# Processing file [968/7500]
#   Features:       0
# Processing file [969/7500]
#   Features:       0
# Processing file [970/7500]
#   Features:       0
# Processing file [971/7500]
#   Features:       0
# Processing file [972/7500]
#   Features:       0
# Processing file [973/7500]
#   Features:       0
# Processing file [974/7500]
#   Features:       0
# Processing file [975/7500]
#   Features:       0
# Processing file [976/7500]
#   Features:       0
# Processing file [977/7500]
#   Features:       0
# Processing file [978/7500]
#   Features:       0
# Processing file [979/7500]
#   Features:       0
# Processing file [980/7500]
#   Features:       0
# Processing file [981/7500]
#   Features:       0
# Processing file [982/7500]
#   Features:       0
# Processing file [983/7500]
#   Features:       0
# Processing file [984/7500]
#   Features:       0
# Processing file [985/7500]
#   Features:       0
# Processing file [986/7500]
#   Features:       0
# Processing file [987/7500]
#   Features:       0
# Processing file [988/7500]
#   Features:       0
# Processing file [989/7500]
#   Features:       0
# Processing file [990/7500]
#   Features:       0
# Processing file [991/7500]
#   Features:       0
# Processing file [992/7500]
#   Features:       0
# Processing file [993/7500]
#   Features:       0
# Processing file [994/7500]
#   Features:       0
# Processing file [995/7500]
#   Features:       0
# Processing file [996/7500]
#   Features:       0
# Processing file [997/7500]
#   Features:       0
# Processing file [998/7500]
#   Features:       0
# Processing file [999/7500]
#   Features:       0
# Processing file [1000/7500]
#   Features:       0
# Processing file [1001/7500]
#   Features:       0
# Processing file [1002/7500]
#   Features:       0
# Processing file [1003/7500]
#   Features:       0
# Processing file [1004/7500]
#   Features:       0
# Processing file [1005/7500]
#   Features:       0
# Processing file [1006/7500]
#   Features:       0
# Processing file [1007/7500]
#   Features:       0
# Processing file [1008/7500]
#   Features:       0
# Processing file [1009/7500]
#   Features:       0
# Processing file [1010/7500]
#   Features:       0
# Processing file [1011/7500]
#   Features:       0
# Processing file [1012/7500]
#   Features:       0
# Processing file [1013/7500]
#   Features:       0
# Processing file [1014/7500]
#   Features:       0
# Processing file [1015/7500]
#   Features:       0
# Processing file [1016/7500]
#   Features:       0
# Processing file [1017/7500]
# ...
#   Features:       0
# Processing file [7210/7500]
#   Features:       0
# Processing file [7211/7500]
#   Features:       0
# Processing file [7212/7500]
#   Features:       0
# Processing file [7213/7500]
#   Features:       0
# Processing file [7214/7500]
#   Features:       0
# Processing file [7215/7500]
#   Features:       0
# Processing file [7216/7500]
#   Features:       0
# Processing file [7217/7500]
#   Features:       0
# Processing file [7218/7500]
#   Features:       0
# Processing file [7219/7500]
#   Features:       0
# Processing file [7220/7500]
#   Features:       0
# Processing file [7221/7500]
#   Features:       0
# Processing file [7222/7500]
#   Features:       0
# Processing file [7223/7500]
#   Features:       0
# Processing file [7224/7500]
#   Features:       0
# Processing file [7225/7500]
#   Features:       0
# Processing file [7226/7500]
#   Features:       0
# Processing file [7227/7500]
#   Features:       0
# Processing file [7228/7500]
#   Features:       0
# Processing file [7229/7500]
#   Features:       0
# Processing file [7230/7500]
#   Features:       0
# Processing file [7231/7500]
#   Features:       0
# Processing file [7232/7500]
#   Features:       0
# Processing file [7233/7500]
#   Features:       0
# Processing file [7234/7500]
#   Features:       0
# Processing file [7235/7500]
#   Features:       0
# Processing file [7236/7500]
#   Features:       0
# Processing file [7237/7500]
#   Features:       0
# Processing file [7238/7500]
#   Features:       0
# Processing file [7239/7500]
#   Features:       0
# Processing file [7240/7500]
#   Features:       0
# Processing file [7241/7500]
#   Features:       0
# Processing file [7242/7500]
#   Features:       0
# Processing file [7243/7500]
#   Features:       0
# Processing file [7244/7500]
#   Features:       0
# Processing file [7245/7500]
#   Features:       0
# Processing file [7246/7500]
#   Features:       0
# Processing file [7247/7500]
#   Features:       0
# Processing file [7248/7500]
#   Features:       0
# Processing file [7249/7500]
#   Features:       0
# Processing file [7250/7500]
#   Features:       0
# Processing file [7251/7500]
#   Features:       0
# Processing file [7252/7500]
#   Features:       0
# Processing file [7253/7500]
#   Features:       0
# Processing file [7254/7500]
#   Features:       0
# Processing file [7255/7500]
#   Features:       0
# Processing file [7256/7500]
#   Features:       0
# Processing file [7257/7500]
#   Features:       0
# Processing file [7258/7500]
#   Features:       0
# Processing file [7259/7500]
#   Features:       0
# Processing file [7260/7500]
#   Features:       0
# Processing file [7261/7500]
#   Features:       0
# Processing file [7262/7500]
#   Features:       0
# Processing file [7263/7500]
#   Features:       0
# Processing file [7264/7500]
#   Features:       0
# Processing file [7265/7500]
#   Features:       0
# Processing file [7266/7500]
#   Features:       0
# Processing file [7267/7500]
#   Features:       0
# Processing file [7268/7500]
#   Features:       0
# Processing file [7269/7500]
#   Features:       0
# Processing file [7270/7500]
#   Features:       0
# Processing file [7271/7500]
#   Features:       0
# Processing file [7272/7500]
#   Features:       0
# Processing file [7273/7500]
#   Features:       0
# Processing file [7274/7500]
#   Features:       0
# Processing file [7275/7500]
#   Features:       0
# Processing file [7276/7500]
#   Features:       0
# Processing file [7277/7500]
#   Features:       0
# Processing file [7278/7500]
#   Features:       0
# Processing file [7279/7500]
#   Features:       0
# Processing file [7280/7500]
#   Features:       0
# Processing file [7281/7500]
#   Features:       0
# Processing file [7282/7500]
#   Features:       0
# Processing file [7283/7500]
#   Features:       0
# Processing file [7284/7500]
#   Features:       0
# Processing file [7285/7500]
#   Features:       0
# Processing file [7286/7500]
#   Features:       0
# Processing file [7287/7500]
#   Features:       0
# Processing file [7288/7500]
#   Features:       0
# Processing file [7289/7500]
#   Features:       0
# Processing file [7290/7500]
#   Features:       0
# Processing file [7291/7500]
#   Features:       0
# Processing file [7292/7500]
#   Features:       0
# Processing file [7293/7500]
#   Features:       0
# Processing file [7294/7500]
#   Features:       0
# Processing file [7295/7500]
#   Features:       0
# Processing file [7296/7500]
#   Features:       0
# Processing file [7297/7500]
#   Features:       0
# Processing file [7298/7500]
#   Features:       0
# Processing file [7299/7500]
#   Features:       0
# Processing file [7300/7500]
#   Features:       0
# Processing file [7301/7500]
#   Features:       0
# Processing file [7302/7500]
#   Features:       0
# Processing file [7303/7500]
#   Features:       0
# Processing file [7304/7500]
#   Features:       0
# Processing file [7305/7500]
#   Features:       0
# Processing file [7306/7500]
#   Features:       0
# Processing file [7307/7500]
#   Features:       0
# Processing file [7308/7500]
#   Features:       0
# Processing file [7309/7500]
#   Features:       0
# Processing file [7310/7500]
#   Features:       0
# Processing file [7311/7500]
#   Features:       0
# Processing file [7312/7500]
#   Features:       0
# Processing file [7313/7500]
#   Features:       0
# Processing file [7314/7500]
#   Features:       0
# Processing file [7315/7500]
#   Features:       0
# Processing file [7316/7500]
#   Features:       0
# Processing file [7317/7500]
#   Features:       0
# Processing file [7318/7500]
#   Features:       0
# Processing file [7319/7500]
#   Features:       0
# Processing file [7320/7500]
#   Features:       0
# Processing file [7321/7500]
#   Features:       0
# Processing file [7322/7500]
#   Features:       0
# Processing file [7323/7500]
#   Features:       0
# Processing file [7324/7500]
#   Features:       0
# Processing file [7325/7500]
#   Features:       0
# Processing file [7326/7500]
#   Features:       0
# Processing file [7327/7500]
#   Features:       0
# Processing file [7328/7500]
#   Features:       0
# Processing file [7329/7500]
#   Features:       0
# Processing file [7330/7500]
#   Features:       0
# Processing file [7331/7500]
#   Features:       0
# Processing file [7332/7500]
#   Features:       0
# Processing file [7333/7500]
#   Features:       0
# Processing file [7334/7500]
#   Features:       0
# Processing file [7335/7500]
#   Features:       0
# Processing file [7336/7500]
#   Features:       0
# Processing file [7337/7500]
#   Features:       0
# Processing file [7338/7500]
#   Features:       0
# Processing file [7339/7500]
#   Features:       0
# Processing file [7340/7500]
#   Features:       0
# Processing file [7341/7500]
#   Features:       0
# Processing file [7342/7500]
#   Features:       0
# Processing file [7343/7500]
#   Features:       0
# Processing file [7344/7500]
#   Features:       0
# Processing file [7345/7500]
#   Features:       0
# Processing file [7346/7500]
#   Features:       0
# Processing file [7347/7500]
#   Features:       0
# Processing file [7348/7500]
#   Features:       0
# Processing file [7349/7500]
#   Features:       0
# Processing file [7350/7500]
#   Features:       0
# Processing file [7351/7500]
#   Features:       0
# Processing file [7352/7500]
#   Features:       0
# Processing file [7353/7500]
#   Features:       0
# Processing file [7354/7500]
#   Features:       0
# Processing file [7355/7500]
#   Features:       0
# Processing file [7356/7500]
#   Features:       0
# Processing file [7357/7500]
#   Features:       0
# Processing file [7358/7500]
#   Features:       0
# Processing file [7359/7500]
#   Features:       0
# Processing file [7360/7500]
#   Features:       0
# Processing file [7361/7500]
#   Features:       0
# Processing file [7362/7500]
#   Features:       0
# Processing file [7363/7500]
#   Features:       0
# Processing file [7364/7500]
#   Features:       0
# Processing file [7365/7500]
#   Features:       0
# Processing file [7366/7500]
#   Features:       0
# Processing file [7367/7500]
#   Features:       0
# Processing file [7368/7500]
#   Features:       0
# Processing file [7369/7500]
#   Features:       0
# Processing file [7370/7500]
#   Features:       0
# Processing file [7371/7500]
#   Features:       0
# Processing file [7372/7500]
#   Features:       0
# Processing file [7373/7500]
#   Features:       0
# Processing file [7374/7500]
#   Features:       0
# Processing file [7375/7500]
#   Features:       0
# Processing file [7376/7500]
#   Features:       0
# Processing file [7377/7500]
#   Features:       0
# Processing file [7378/7500]
#   Features:       0
# Processing file [7379/7500]
#   Features:       0
# Processing file [7380/7500]
#   Features:       0
# Processing file [7381/7500]
#   Features:       0
# Processing file [7382/7500]
#   Features:       0
# Processing file [7383/7500]
#   Features:       0
# Processing file [7384/7500]
#   Features:       0
# Processing file [7385/7500]
#   Features:       0
# Processing file [7386/7500]
#   Features:       0
# Processing file [7387/7500]
#   Features:       0
# Processing file [7388/7500]
#   Features:       0
# Processing file [7389/7500]
#   Features:       0
# Processing file [7390/7500]
#   Features:       0
# Processing file [7391/7500]
#   Features:       0
# Processing file [7392/7500]
#   Features:       0
# Processing file [7393/7500]
#   Features:       0
# Processing file [7394/7500]
#   Features:       0
# Processing file [7395/7500]
#   Features:       0
# Processing file [7396/7500]
#   Features:       0
# Processing file [7397/7500]
#   Features:       0
# Processing file [7398/7500]
#   Features:       0
# Processing file [7399/7500]
#   Features:       0
# Processing file [7400/7500]
#   Features:       0
# Processing file [7401/7500]
#   Features:       0
# Processing file [7402/7500]
#   Features:       0
# Processing file [7403/7500]
#   Features:       0
# Processing file [7404/7500]
#   Features:       0
# Processing file [7405/7500]
#   Features:       0
# Processing file [7406/7500]
#   Features:       0
# Processing file [7407/7500]
#   Features:       0
# Processing file [7408/7500]
#   Features:       0
# Processing file [7409/7500]
#   Features:       0
# Processing file [7410/7500]
#   Features:       0
# Processing file [7411/7500]
#   Features:       0
# Processing file [7412/7500]
#   Features:       0
# Processing file [7413/7500]
#   Features:       0
# Processing file [7414/7500]
#   Features:       0
# Processing file [7415/7500]
#   Features:       0
# Processing file [7416/7500]
#   Features:       0
# Processing file [7417/7500]
#   Features:       0
# Processing file [7418/7500]
#   Features:       0
# Processing file [7419/7500]
#   Features:       0
# Processing file [7420/7500]
#   Features:       0
# Processing file [7421/7500]
#   Features:       0
# Processing file [7422/7500]
#   Features:       0
# Processing file [7423/7500]
#   Features:       0
# Processing file [7424/7500]
#   Features:       0
# Processing file [7425/7500]
#   Features:       0
# Processing file [7426/7500]
#   Features:       0
# Processing file [7427/7500]
#   Features:       0
# Processing file [7428/7500]
#   Features:       0
# Processing file [7429/7500]
#   Features:       0
# Processing file [7430/7500]
#   Features:       0
# Processing file [7431/7500]
#   Features:       0
# Processing file [7432/7500]
#   Features:       0
# Processing file [7433/7500]
#   Features:       0
# Processing file [7434/7500]
#   Features:       0
# Processing file [7435/7500]
#   Features:       0
# Processing file [7436/7500]
#   Features:       0
# Processing file [7437/7500]
#   Features:       0
# Processing file [7438/7500]
#   Features:       0
# Processing file [7439/7500]
#   Features:       0
# Processing file [7440/7500]
#   Features:       0
# Processing file [7441/7500]
#   Features:       0
# Processing file [7442/7500]
#   Features:       0
# Processing file [7443/7500]
#   Features:       0
# Processing file [7444/7500]
#   Features:       0
# Processing file [7445/7500]
#   Features:       0
# Processing file [7446/7500]
#   Features:       0
# Processing file [7447/7500]
#   Features:       0
# Processing file [7448/7500]
#   Features:       0
# Processing file [7449/7500]
#   Features:       0
# Processing file [7450/7500]
#   Features:       0
# Processing file [7451/7500]
#   Features:       0
# Processing file [7452/7500]
#   Features:       0
# Processing file [7453/7500]
#   Features:       0
# Processing file [7454/7500]
#   Features:       0
# Processing file [7455/7500]
#   Features:       0
# Processing file [7456/7500]
#   Features:       0
# Processing file [7457/7500]
#   Features:       0
# Processing file [7458/7500]
#   Features:       0
# Processing file [7459/7500]
#   Features:       0
# Processing file [7460/7500]
#   Features:       0
# Processing file [7461/7500]
#   Features:       0
# Processing file [7462/7500]
#   Features:       0
# Processing file [7463/7500]
#   Features:       0
# Processing file [7464/7500]
#   Features:       0
# Processing file [7465/7500]
#   Features:       0
# Processing file [7466/7500]
#   Features:       0
# Processing file [7467/7500]
#   Features:       0
# Processing file [7468/7500]
#   Features:       0
# Processing file [7469/7500]
#   Features:       0
# Processing file [7470/7500]
#   Features:       0
# Processing file [7471/7500]
#   Features:       0
# Processing file [7472/7500]
#   Features:       0
# Processing file [7473/7500]
#   Features:       0
# Processing file [7474/7500]
#   Features:       0
# Processing file [7475/7500]
#   Features:       0
# Processing file [7476/7500]
#   Features:       0
# Processing file [7477/7500]
#   Features:       0
# Processing file [7478/7500]
#   Features:       0
# Processing file [7479/7500]
#   Features:       0
# Processing file [7480/7500]
#   Features:       0
# Processing file [7481/7500]
#   Features:       0
# Processing file [7482/7500]
#   Features:       0
# Processing file [7483/7500]
#   Features:       0
# Processing file [7484/7500]
#   Features:       0
# Processing file [7485/7500]
#   Features:       0
# Processing file [7486/7500]
#   Features:       0
# Processing file [7487/7500]
#   Features:       0
# Processing file [7488/7500]
#   Features:       0
# Processing file [7489/7500]
#   Features:       0
# Processing file [7490/7500]
#   Features:       0
# Processing file [7491/7500]
#   Features:       0
# Processing file [7492/7500]
#   Features:       0
# Processing file [7493/7500]
#   Features:       0
# Processing file [7494/7500]
#   Features:       0
# Processing file [7495/7500]
#   Features:       0
# Processing file [7496/7500]
#   Features:       0
# Processing file [7497/7500]
#   Features:       0
# Processing file [7498/7500]
#   Features:       0
# Processing file [7499/7500]
#   Features:       0
# Processing file [7500/7500]
#   Features:       0
# Elapsed time: 0.323 [minutes]
# [10/16/2021 16:30:09 INFO] Importing features into the database...
# 100%|██████████| 7500/7500 [00:02<00:00, 2741.97it/s]
# [10/16/2021 16:30:12 INFO] Importing matches into the database...
#   0%|          | 0/30000 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# IntegrityError                            Traceback (most recent call last)
# /tmp/ipykernel_19051/3079991929.py in <module>
#       2 match_path = outputs / 'feats-superpoint-n4096-r1024_matches-superglue_pairs-manual-db-covis5.h5'
#       3
# ----> 4 reconstruction.main(sfm_dir, images / 'train', sfm_pairs, feature_path, match_path, skip_geometric_verification = True)
#
# ~/Hierarchical-Localization/hloc/reconstruction.py in main(sfm_dir, image_dir, pairs, features, matches, colmap_path, single_camera, skip_geometric_verification, min_match_score, min_num_matches)
#     138     import_features(image_ids, database, features)
#     139     import_matches(image_ids, database, pairs, matches,
# --> 140                    min_match_score, skip_geometric_verification)
#     141     if not skip_geometric_verification:
#     142         geometric_verification(colmap_path, database, pairs)
#
# ~/Hierarchical-Localization/hloc/triangulation.py in import_matches(image_ids, database_path, pairs_path, matches_path, min_match_score, skip_geometric_verification)
#     101         matches = np.stack([np.where(valid)[0], matches[valid]], -1)
#     102
# --> 103         db.add_matches(id0, id1, matches)
#     104         matched |= {(id0, id1), (id1, id0)}
#     105
#
# ~/Hierarchical-Localization/hloc/utils/database.py in add_matches(self, image_id1, image_id2, matches)
#     205         self.execute(
#     206             "INSERT INTO matches VALUES (?, ?, ?, ?)",
# --> 207             (pair_id,) + matches.shape + (array_to_blob(matches),))
#     208
#     209     def add_two_view_geometry(self, image_id1, image_id2, matches,
#
# IntegrityError: UNIQUE constraint failed: matches.pair_id

# %%
# Run matches.importer manually

# colmap matches_importer --database_path outputs/COMP90086/sfm_superpoint+superglue/database.db --match_list_path outputs/COMP90086/pairs-manual-db-covis5.txt --match_type pairs --SiftMatching.max_num_trials 20000 --SiftMatching.min_inlier_ratio 0.1 --SiftMatching.use_gpu 0

# %% [markdown]
# ## Visualization
# We visualize some of the registered images, and color their keypoint by visibility, track length, or triangulated depth.

# %%
visualization.visualize_sfm_2d(sfm_dir, images, color_by='visibility', n=5)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_19051/709537630.py in <module>
# ----> 1 visualization.visualize_sfm_2d(sfm_dir, images, color_by='visibility', n=5)
#
# ~/Hierarchical-Localization/hloc/visualization.py in visualize_sfm_2d(sfm_model, image_dir, color_by, selected, n, seed, dpi)
#      15     assert image_dir.exists()
#      16
# ---> 17     images = read_images_binary(sfm_model / 'images.bin')
#      18     if color_by in ['track_length', 'depth']:
#      19         points3D = read_points3D_binary(sfm_model / 'points3D.bin')
#
# ~/Hierarchical-Localization/hloc/utils/read_write_model.py in read_images_binary(path_to_model_file)
#     230     """
#     231     images = {}
# --> 232     with open(path_to_model_file, "rb") as fid:
#     233         num_reg_images = read_next_bytes(fid, 8, "Q")[0]
#     234         for _ in range(num_reg_images):
#
# FileNotFoundError: [Errno 2] No such file or directory: 'outputs/COMP90086/sfm_superpoint+superglue/images.bin'

# %%
visualization.visualize_sfm_2d(sfm_dir, images, color_by='track_length', n=5)

# %%
visualization.visualize_sfm_2d(sfm_dir, images, color_by='depth', n=5)

# %% [markdown]
# # TODO: When querying

# %% [markdown]
# ## Generate pairs for the SfM reconstruction
#
# Instead of matching all database images exhaustively, we exploit the existing SIFT model to find which image pairs are the most covisible.
# We first convert the SIFT model from the NVM to the COLMAP format, and then do a covisiblity search, selecting the top 20 most covisibile neighbors for each image.

# %%
num_covis = 20
# top-k most covisible in SIFT model
sfm_pairs = outputs / f'pairs-db-covis{num_covis}.txt'

sift_sfm = dataset / '3D-models/aachen_v_1_1'

# %%
pairs_from_covisibility.main(
    sift_sfm, sfm_pairs, num_matched=20)

# %%
sfm_matches = match_features.main(
    matcher_conf, sfm_pairs, feature_conf['output'], outputs)

# %% [markdown]
# ## Match the database images
#
# The function returns the path of the file in which all the computed matches are stored

# %%
#sfm_match_path = match_features.main(matcher_conf, sfm_pairs, feature_conf['output'], outputs)

# %% [markdown]
# ## Match the query images
#
# We try to find matches for the given images by using `hloc/pairs_from_retrieval.py`.

# %%
# Output top 50 matches
netvlad_top_k = 50


# Output file with pairs
# top-k retrieved by NetVLAD
loc_pairs = outputs / f'pairs-query-netvlad{netvlad_top_k}.txt'

# %%
# Query images have 'test' prefix, db images have 'train' prefix
pairs_from_retrieval.main(
    feature_path, loc_pairs, netvlad_top_k,
    query_prefix='test', db_prefix = 'train', db_model=sfm_dir)
# Out:
# [10/16/2021 14:29:04 INFO] Extracting image pairs from a retrieval database.
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_13597/2450759520.py in <module>
#       2 pairs_from_retrieval.main(
#       3     feature_path, loc_pairs, netvlad_top_k,
# ----> 4     query_prefix='test', db_prefix = 'train', db_model=sfm_dir)
#
# ~/Hierarchical-Localization/hloc/pairs_from_retrieval.py in main(descriptors, output, num_matched, query_prefix, query_list, db_prefix, db_list, db_model, db_descriptors)
#      44
#      45     if db_model:
# ---> 46         images = read_images_binary(db_model / 'images.bin')
#      47         db_names = [i.name for i in images.values()]
#      48     else:
#
# ~/Hierarchical-Localization/hloc/utils/read_write_model.py in read_images_binary(path_to_model_file)
#     230     """
#     231     images = {}
# --> 232     with open(path_to_model_file, "rb") as fid:
#     233         num_reg_images = read_next_bytes(fid, 8, "Q")[0]
#     234         for _ in range(num_reg_images):
#
# FileNotFoundError: [Errno 2] No such file or directory: 'outputs/COMP90086/sfm_superpoint+superglue/images.bin'

# %%
match_path = match_features.main(
    matcher_conf, loc_pairs, feature_conf['output'], outputs)

# %% [markdown]
# # Localize the query images
#
# We finally perform localization via `hloc.localize_sfm.py`

# %%
results = outputs / f'COMP90086_hloc_superpoint+superglue_netvlad{netvlad_top_k}.txt'
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2483/2873987140.py in <module>
# ----> 1 results = outputs / f'COMP90086_hloc_superpoint+superglue_netvlad{netvlad_top_k}.txt'
#
# NameError: name 'netvlad_top_k' is not defined

# %%
localize_sfm.main(
    sfm_dir, #Done
    outputs / 'query_list_with_intrinsics.txt', #DONE
    loc_pairs, # DONE
    feature_path, #DONE
    match_path, #DONE
    results, # Done
    covisibility_clustering=False)  # not required with SuperPoint+SuperGlue
