# %%
import torch, os
import torchvision.transforms as T
from torch.utils.data import Dataset
import torch.nn as nn
import torch.optim as optim
import numpy as np
import pandas as pd 
from tqdm import tqdm
from PIL import Image
from sklearn.neighbors import NearestNeighbors

# %%
if torch.cuda.is_available():
    device = "cuda"
else:
    device = "cpu"

# %%
train_df = pd.read_csv("./data/COMP90086_2021_Project_train/train.csv")
test_df = pd.read_csv("./data/COMP90086_2021_Project_test/imagenames.csv")
test_df
# Out:
#              id
# 0     IMG4287_3
# 1     IMG4288_5
# 2     IMG4289_5
# 3     IMG4290_4
# 4     IMG4291_5
# ...         ...
# 1195  IMG5482_1
# 1196  IMG5483_2
# 1197  IMG5484_4
# 1198  IMG5485_3
# 1199  IMG5486_2
#
# [1200 rows x 1 columns]

# %%
# SOURCE: https://medium.com/pytorch/image-similarity-search-in-pytorch-1a744cf3469
# Dataset class converting all images in the train/test folder to PyTorch dataset
class FolderDataset(Dataset):
    """
    Creates a PyTorch dataset from a given folder containing images and returns two tensor images. 
    :param main_dir: directory where images are stored.
    #:param transform: torchvision transforms to be applied while making dataset (optional) 
    :return: two images, one as input to the model and another image to compare with the original image for reconstruction.
    """
    def __init__(self, main_dir, transform=None):
        self.main_dir = main_dir
        self.transform = transform
        self.all_imgs = os.listdir(main_dir)

    def __len__(self):
        return len(self.all_imgs)

    def __getitem__(self, idx):
        img_loc = os.path.join(self.main_dir, self.all_imgs[idx])

        
        image = Image.open(img_loc).convert("RGB") 
        crop = T.Compose([T.CenterCrop((480, 640))])
        image = crop(image)

        if self.transform is not None:
            tensor_image = self.transform(image)

        return tensor_image, tensor_image

# %%
class ConvEncoder(nn.Module):
    """
    Convolutional Encoder Model which is a a repetition of convolutional, relu and maxpool layers.
    It converts an input images to a feature representation of size (1, 256, 16, 16).
    """

    def __init__(self):
        super().__init__()
        self.conv1 = nn.Conv2d(3, 16, (3, 3), padding=(1, 1))
        self.relu1 = nn.ReLU(inplace=True)
        self.maxpool1 = nn.MaxPool2d((2, 2))
        self.conv2 = nn.Conv2d(16, 32, (3, 3), padding=(1, 1))
        self.relu2 = nn.ReLU(inplace=True)
        self.maxpool2 = nn.MaxPool2d((2, 2))
        self.conv3 = nn.Conv2d(32, 64, (3, 3), padding=(1, 1))
        self.relu3 = nn.ReLU(inplace=True)
        self.maxpool3 = nn.MaxPool2d((2, 2))
        self.conv4 = nn.Conv2d(64, 128, (3, 3), padding=(1, 1))
        self.relu4 = nn.ReLU(inplace=True)
        self.maxpool4 = nn.MaxPool2d((2, 2))
        self.conv5 = nn.Conv2d(128, 256, (3, 3), padding=(1, 1))
        self.relu5 = nn.ReLU(inplace=True)
        self.maxpool5 = nn.MaxPool2d((2, 2))

    def forward(self, x):
        # Downscale the image with conv maxpool
        x = self.conv1(x)
        x = self.relu1(x)
        x = self.maxpool1(x)
        x = self.conv2(x)
        x = self.relu2(x)
        x = self.maxpool2(x)
        x = self.conv3(x)
        x = self.relu3(x)
        x = self.maxpool3(x)
        x = self.conv4(x)
        x = self.relu4(x)
        x = self.maxpool4(x)
        x = self.conv5(x)
        x = self.relu5(x)
        x = self.maxpool5(x)
        
        return x

# %%
class ConvDecoder(nn.Module):
    """
    Convolutional Decoder Model takes an input of feature representations and reconstructs back the image
    It upscales the feature representations to the original image using transposed convolution layers of kernel size (2, 2) and stride (2, 2)
    """

    def __init__(self):
        super().__init__()
        self.deconv1 = nn.ConvTranspose2d(256, 128, (2, 2), stride=(2, 2))
        self.relu1 = nn.ReLU(inplace=True)
        self.deconv2 = nn.ConvTranspose2d(128, 64, (2, 2), stride=(2, 2))
        self.relu2 = nn.ReLU(inplace=True)
        self.deconv3 = nn.ConvTranspose2d(64, 32, (2, 2), stride=(2, 2))
        self.relu3 = nn.ReLU(inplace=True)
        self.deconv4 = nn.ConvTranspose2d(32, 16, (2, 2), stride=(2, 2))
        self.relu4 = nn.ReLU(inplace=True)
        self.deconv5 = nn.ConvTranspose2d(16, 3, (2, 2), stride=(2, 2))
        self.relu5 = nn.ReLU(inplace=True)

    def forward(self, x):
        # Upscale the image with convtranspose etc.
        x = self.deconv1(x)
        x = self.relu1(x)
        x = self.deconv2(x)
        x = self.relu2(x)
        x = self.deconv3(x)
        x = self.relu3(x)
        x = self.deconv4(x)
        x = self.relu4(x)
        x = self.deconv5(x)
        x = self.relu5(x)
        return x

# %%
def train_step(encoder, decoder, train_loader, loss_fn, optimizer, device):
    """
    Performs a single training step
    :param encoder: the convolutional Encoder defined as ConvEncoder
    :param decoder: A convolutional Decoder defined as ConvDecoder
    :param train_loader: PyTorch dataloader, containing (images, images).
    :param loss_fn: PyTorch loss_fn to compute loss between 2 images.
    :param optimizer: PyTorch optimizer (eg. AdamW)
    :param device: "cuda" or "cpu"
    :returns: Train Loss
    """
    #  Set networks to train mode.
    encoder.train()
    decoder.train()

    for batch_idx, (train_img, target_img) in enumerate(train_loader):
        train_img = train_img.to(device)
        target_img = target_img.to(device)
        
        # Zero grad the optimizer
        optimizer.zero_grad()
        # Feed the train images to encoder
        enc_output = encoder(train_img)
        dec_output = decoder(enc_output)
        # Compute loss between the reconstructed image and orginal image which is target image.
        loss = loss_fn(dec_output, target_img)
        loss.backward()
        # Apply the optimizer to network
        optimizer.step()
    return loss.item()

def val_step(encoder, decoder, val_loader, loss_fn, device):
    """
    Performs a single training step
    :param encoder: A convolutional Encoder like torch_model ConvEncoder
    :param decoder: A convolutional Decoder like torch_model ConvDecoder
    :param val_loader: PyTorch dataloader containing (images, images)
    :param loss_fn: PyTorch loss_fnto compute loss between 2 images
    :param device: "cuda" or "cpu"
    :returns: Validation Loss
    """
    # Set to eval mode.
    encoder.eval()
    decoder.eval()
    
    # gradients do not need to be computed  for validation???
    with torch.no_grad():
        for batch_idx, (train_img, target_img) in enumerate(val_loader):
            train_img = train_img.to(device)
            target_img = target_img.to(device)
            # Feed the train images to encoder
            enc_output = encoder(train_img)
            # Feed the encoder output to Decoder to reconstruct the image
            dec_output = decoder(enc_output)
            # Find the validation loss for the encoder and decoder 
            loss = loss_fn(dec_output, target_img)
    return loss.item()

# %%
def create_embedding(encoder, full_loader, embedding_dim, device):
    """
    Creates embedding using encoder from dataloader and saves our image embeddings.
    :param encoder: A convolutional Encoder like torch_model ConvEncoder
    :param full_loader: PyTorch dataloader, containing (images, images) over the entire dataset
    :param embedding_dim: Tuple (c, h, w) Dimension of embedding = output of encoder dimesntions.
    :param device: "cuda" or "cpu"
    : return: Embedding of size (num_images_in_loader + 1, c, h, w)
    """
    # Set encoder to eval mode.
    encoder.eval()
    # Just a place holder for our 0th image embedding.
    embedding = torch.randn(embedding_dim)
    
    # no_grad as we do not compute loss here
    with torch.no_grad():
        for batch_idx, (train_img, target_img) in enumerate(full_loader):
            train_img = train_img.to(device)
            # Get encoder outputs and move outputs to cpu
            enc_output = encoder(train_img).cpu()
            # Add the outputs to embeddings
            embedding = torch.cat((embedding, enc_output), 0)
    return embedding

# %%
# Create the PyTorch `dataset` and the `dataloaders`
transforms = T.Compose([T.ToTensor()]) # Normalize the pixels and convert to tensor
# Create folder dataset
full_dataset = FolderDataset("./data/COMP90086_2021_Project_train/train", transforms) 

train_size = int(0.75 * len(full_dataset))
val_size = len(full_dataset) - train_size

# Split data to train and test
train_dataset, val_dataset = torch.utils.data.random_split(full_dataset, [train_size, val_size])

# Create the train dataloader
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=32, shuffle=True)
# Create the validation dataloader
val_loader = torch.utils.data.DataLoader(val_dataset, batch_size=32)

# Create the full dataloader
full_loader = torch.utils.data.DataLoader(full_dataset, batch_size=32)

# Mean squared lossto compute difference between two images
encoder = ConvEncoder() 
decoder = ConvDecoder()
device = "cuda" 
max_loss = 9999

# Shift models to GPU
encoder.to(device)
decoder.to(device)

# The enocder and decoder parameters
print(encoder.parameters())
autoencoder_params = list(encoder.parameters()) + list(decoder.parameters())
# Adam Optimizer
optimizer = optim.AdamW(autoencoder_params, lr=1e-3)

total_epochs = 20


for epoch in tqdm(range(total_epochs)):
        train_loss = train_step(encoder, decoder, train_loader, nn.MSELoss(), optimizer, device=device)   
        print(f"Epochs = {epoch}, Training Loss : {train_loss}")
        val_loss = val_step(encoder, decoder, val_loader, nn.MSELoss(), device=device)   
        print(f"Epochs = {epoch}, Validation Loss : {val_loss}")
        # Simple Best Model saving
        if val_loss < max_loss:
            print("Validation Loss decreased, saving new best model")
            torch.save(encoder.state_dict(), "encoder_model.pt")
            torch.save(decoder.state_dict(), "decoder_model.pt")
# Out:
# <generator object Module.parameters at 0x7f354b0b46d0>
#   0%|          | 0/20 [00:00<?, ?it/s]
# Epochs = 0, Training Loss : 0.01252690702676773
#   5%|▌         | 1/20 [01:59<37:46, 119.29s/it]
# Epochs = 0, Validation Loss : 0.01323419064283371
# Validation Loss decreased, saving new best model
# Epochs = 1, Training Loss : 0.007552537601441145
#  10%|█         | 2/20 [03:46<33:35, 112.00s/it]
# Epochs = 1, Validation Loss : 0.010019776411354542
# Validation Loss decreased, saving new best model
# Epochs = 2, Training Loss : 0.006785946898162365
#  15%|█▌        | 3/20 [05:33<31:04, 109.70s/it]
# Epochs = 2, Validation Loss : 0.008748156018555164
# Validation Loss decreased, saving new best model
# Epochs = 3, Training Loss : 0.004905642941594124
#  20%|██        | 4/20 [07:20<28:57, 108.59s/it]
# Epochs = 3, Validation Loss : 0.006146470550447702
# Validation Loss decreased, saving new best model
# Epochs = 4, Training Loss : 0.004520830698311329
#  25%|██▌       | 5/20 [09:07<27:02, 108.17s/it]
# Epochs = 4, Validation Loss : 0.005630096886307001
# Validation Loss decreased, saving new best model
# Epochs = 5, Training Loss : 0.003535803873091936
#  30%|███       | 6/20 [10:54<25:09, 107.82s/it]
# Epochs = 5, Validation Loss : 0.0053911879658699036
# Validation Loss decreased, saving new best model
# Epochs = 6, Training Loss : 0.004147941246628761
#  35%|███▌      | 7/20 [12:41<23:19, 107.62s/it]
# Epochs = 6, Validation Loss : 0.00537729961797595
# Validation Loss decreased, saving new best model
# Epochs = 7, Training Loss : 0.0033578905276954174
#  40%|████      | 8/20 [14:28<21:29, 107.47s/it]
# Epochs = 7, Validation Loss : 0.005101591348648071
# Validation Loss decreased, saving new best model
# Epochs = 8, Training Loss : 0.0041295913979411125
#  45%|████▌     | 9/20 [16:16<19:41, 107.43s/it]
# Epochs = 8, Validation Loss : 0.005190403666347265
# Validation Loss decreased, saving new best model
# Epochs = 9, Training Loss : 0.00450908113270998
#  50%|█████     | 10/20 [18:03<17:53, 107.39s/it]
# Epochs = 9, Validation Loss : 0.004838699474930763
# Validation Loss decreased, saving new best model
# Epochs = 10, Training Loss : 0.0036463518626987934
#  55%|█████▌    | 11/20 [19:51<16:06, 107.43s/it]
# Epochs = 10, Validation Loss : 0.00461912015452981
# Validation Loss decreased, saving new best model
# Epochs = 11, Training Loss : 0.0035323232877999544
#  60%|██████    | 12/20 [21:38<14:19, 107.38s/it]
# Epochs = 11, Validation Loss : 0.004435521550476551
# Validation Loss decreased, saving new best model
# Epochs = 12, Training Loss : 0.003761634463444352
#  65%|██████▌   | 13/20 [23:25<12:31, 107.41s/it]
# Epochs = 12, Validation Loss : 0.0042784851975739
# Validation Loss decreased, saving new best model
# Epochs = 13, Training Loss : 0.004761117976158857
#  70%|███████   | 14/20 [25:13<10:44, 107.43s/it]
# Epochs = 13, Validation Loss : 0.0072531807236373425
# Validation Loss decreased, saving new best model
# Epochs = 14, Training Loss : 0.0032836939208209515
#  75%|███████▌  | 15/20 [27:01<08:57, 107.53s/it]
# Epochs = 14, Validation Loss : 0.004034943878650665
# Validation Loss decreased, saving new best model
# Epochs = 15, Training Loss : 0.0032015249598771334
#  80%|████████  | 16/20 [28:48<07:10, 107.54s/it]
# Epochs = 15, Validation Loss : 0.003900214098393917
# Validation Loss decreased, saving new best model
# Epochs = 16, Training Loss : 0.0038795953150838614
#  85%|████████▌ | 17/20 [30:36<05:22, 107.61s/it]
# Epochs = 16, Validation Loss : 0.0038666885811835527
# Validation Loss decreased, saving new best model
# Epochs = 17, Training Loss : 0.003770400770008564
#  90%|█████████ | 18/20 [32:24<03:35, 107.69s/it]
# Epochs = 17, Validation Loss : 0.004188248887658119
# Validation Loss decreased, saving new best model
# Epochs = 18, Training Loss : 0.002613143529742956
#  95%|█████████▌| 19/20 [34:12<01:47, 107.72s/it]
# Epochs = 18, Validation Loss : 0.0037254728376865387
# Validation Loss decreased, saving new best model
# Epochs = 19, Training Loss : 0.004715657792985439
# 100%|██████████| 20/20 [36:00<00:00, 108.00s/it]
# Epochs = 19, Validation Loss : 0.0037532318383455276
# Validation Loss decreased, saving new best model
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipykernel_19525/2596379651.py in <module>
#      50
#      51 # We need feature representations for the complete dataset as well (i.e full_loader)
# ---> 52 embedding = create_embedding(encoder, full_loader, embedding_shape, device)
#      53 # Convert embedding to numpy and save them
#      54 numpy_embedding = embedding.cpu().detach().numpy()
#
# /tmp/ipykernel_19525/301181842.py in create_embedding(encoder, full_loader, embedding_dim, device)
#      20             enc_output = encoder(train_img).cpu()
#      21             # Add the outputs to embeddings
# ---> 22             embedding = torch.cat((embedding, enc_output), 0)
#      23     return embedding
#
# RuntimeError: torch.cat(): Sizes of tensors must match except in dimension 0. Got 16 and 15 in dimension 2 (The offending index is 1)

# %%
# Got these values from the encoder
embedding_shape = (1, 256, 15, 20)


# We need feature representations for the complete dataset as well (i.e full_loader)
embedding = create_embedding(encoder, full_loader, embedding_shape, device)
# Convert embedding to numpy and save them
numpy_embedding = embedding.cpu().detach().numpy()
print('numpy_embedding:', numpy_embedding)
num_images = numpy_embedding.shape[0]

# Save the embeddings for complete dataset
flattened_embedding = numpy_embedding.reshape((num_images, -1))
np.save("data_embedding.npy", flattened_embedding)
# Out:
# numpy_embedding: [[[[-2.36840653e+00  6.26653016e-01  2.72425920e-01 ...  8.52612436e-01
#      1.43433189e+00 -5.39098144e-01]
#    [-2.94320762e-01  2.51943135e+00 -7.61376679e-01 ...  9.80363488e-01
#      1.47020829e+00  2.02829868e-01]
#    [-3.96223569e+00 -1.96240079e+00  5.09149730e-01 ... -1.19797754e+00
#      1.05913246e+00  2.77655363e-01]
#    ...
#    [-7.77682215e-02  8.89263809e-01 -3.44714433e-01 ...  1.40728140e+00
#     -9.38679934e-01 -9.03505445e-01]
#    [ 5.48914708e-02  1.41774490e-01  9.01549160e-01 ...  1.65012228e+00
#     -4.43023592e-01  5.18196933e-02]
#    [ 1.08886015e+00  1.04408896e+00  1.37463880e+00 ... -3.49601358e-02
#     -2.09944099e-01 -3.88877690e-01]]
#
#   [[ 6.13528609e-01  6.78441107e-01  4.42746542e-02 ...  2.66247940e+00
#     -1.39707431e-01 -5.24485826e-01]
#    [ 4.67617035e-01  6.21322751e-01  3.41062307e-01 ...  3.40247720e-01
#      1.01849988e-01  5.26344836e-01]
#    [-2.03190279e+00 -6.24652505e-01 -2.50390083e-01 ... -6.34851158e-01
#     -7.30638504e-01 -1.48271048e+00]
#    ...
#    [-1.26948535e+00  3.19762677e-01 -1.11194384e+00 ...  5.80612600e-01
#      9.62480247e-01  1.32383573e+00]
#    [-5.98447286e-02 -3.37497517e-02  2.02506140e-01 ...  1.77067518e+00
#      1.59376574e+00  1.18588948e+00]
#    [ 2.25521415e-01 -1.51212418e+00 -1.20988798e+00 ... -1.04264534e+00
#      1.49259937e+00 -3.23061854e-01]]
#
#   [[-6.16124459e-02 -1.62394249e+00 -1.44244778e+00 ...  2.29351923e-01
#     -1.00348866e+00 -5.22266626e-01]
#    [-5.50759971e-01  1.23803008e+00  6.68590963e-01 ...  4.99669947e-02
#     -3.24920893e-01 -9.22044739e-02]
#    [-4.44916993e-01 -6.11124039e-01  9.07100260e-01 ... -1.88773060e+00
#      9.49676707e-02 -9.48251069e-01]
#    ...
#    [ 9.21348572e-01 -3.66423965e-01  8.32223773e-01 ... -1.49460161e+00
#     -2.11789832e-01  6.32564068e-01]
#    [-6.81649685e-01 -1.35202181e+00 -6.73329592e-01 ...  5.27275205e-01
#      3.93619657e-01  4.93383944e-01]
#    [ 1.37419605e+00  8.80915999e-01 -9.58874047e-01 ...  5.96078992e-01
#     -3.85175884e-01  6.29342273e-02]]
#
#   ...
#
#   [[-1.11520088e+00  1.96497428e+00 -6.13426685e-01 ... -2.43780583e-01
#     -2.63162941e-01 -6.57993495e-01]
#    [-5.86818218e-01 -5.75809300e-01  1.51657474e+00 ...  8.23704004e-01
#      4.58598047e-01 -1.24861741e+00]
#    [-1.21701896e+00 -1.07527651e-01  1.15850382e-02 ... -2.19563437e+00
#     -1.53088903e+00  9.31895971e-01]
#    ...
#    [-8.41175973e-01  2.89019495e-01  5.54276221e-02 ...  5.66542327e-01
#      9.17715907e-01 -4.67611790e-01]
#    [-1.45084262e+00 -1.16012633e+00  1.10436010e+00 ... -1.39537311e+00
#      1.08387923e+00  9.28422451e-01]
#    [-8.40862215e-01  6.71785831e-01 -8.01785409e-01 ...  5.95804513e-01
#     -8.43201578e-01 -9.68119651e-02]]
#
#   [[ 1.88842142e+00 -2.40457445e-01  9.26642239e-01 ...  8.84603977e-01
#     -3.25645387e-01  1.43721238e-01]
#    [ 1.08725876e-01  2.35960305e-01 -2.18484029e-01 ...  1.69713938e+00
#      5.17381549e-01 -1.37868489e-03]
#    [ 1.40506065e+00  5.84288538e-01 -1.15737522e+00 ...  2.45154619e-01
#     -6.16663933e-01  4.95688826e-01]
#    ...
#    [-7.42793679e-01 -9.95780110e-01 -5.80423653e-01 ...  6.67537689e-01
#      3.63880813e-01 -2.29374930e-01]
#    [ 1.80878937e+00  9.93833467e-02 -5.43582439e-01 ...  3.15705836e-01
#     -1.89191718e-02  3.29500169e-01]
#    [-8.34082142e-02  3.59029263e-01 -4.53984827e-01 ... -3.40207905e-01
#      1.32236436e-01 -1.08766413e+00]]
#
#   [[-9.38587844e-01  8.45209777e-01 -1.06115115e+00 ... -1.57169569e+00
#     -9.33152795e-01  3.63988847e-01]
#    [-1.10773027e+00  1.69530821e+00 -4.40462947e-01 ...  2.22625360e-01
#     -1.44112456e+00  5.29262304e-01]
#    [-7.07379401e-01 -1.23454735e-01  3.23560387e-01 ... -9.07602668e-01
#      6.33391440e-01  6.29603863e-01]
#    ...
#    [ 7.27279842e-01  6.55265450e-01  1.29848135e+00 ...  1.60567212e+00
#     -1.11069179e+00  8.04679096e-01]
#    [ 9.62599367e-02 -1.12583983e+00 -5.76434657e-02 ...  2.54812717e-01
#     -1.25047326e+00  7.26683378e-01]
#    [-1.95226334e-02 -1.03623235e+00 -1.25523937e+00 ... -5.03075838e-01
#      5.03053479e-02 -1.22413345e-01]]]
#
#
#  [[[ 7.33442247e-01  7.66167164e-01  7.54678667e-01 ...  8.99119198e-01
#      6.46422267e-01  5.03488839e-01]
#    [ 7.03452587e-01  3.82735878e-01  3.86873305e-01 ...  6.80272341e-01
#      3.13039422e-01  7.90355206e-02]
#    [ 7.33111084e-01  3.57737362e-01  3.52288157e-01 ...  7.32047737e-01
#      3.15210819e-01  1.79778337e-01]
#    ...
#    [ 7.61497796e-01  3.88635039e-01  3.39440465e-01 ...  8.83353472e-01
#      5.40679395e-01  1.78419143e-01]
#    [ 7.93698847e-01  3.86799604e-01  3.90239179e-01 ...  8.57704878e-01
#      5.31710029e-01  2.92050481e-01]
#    [ 7.79923141e-01  3.68552208e-01  3.81280661e-01 ...  8.35872948e-01
#      6.06092632e-01  2.63975680e-01]]
#
#   [[ 1.19423890e+00  8.68504822e-01  8.31303239e-01 ...  6.94774747e-01
#      1.12321758e+00  6.60870552e-01]
#    [ 1.16642952e+00  8.98109257e-01  8.90937150e-01 ...  6.97407544e-01
#      8.95521641e-01  7.30532229e-01]
#    [ 1.20528960e+00  8.85727048e-01  9.03608799e-01 ...  8.06083322e-01
#      9.35501814e-01  6.98880196e-01]
#    ...
#    [ 1.20819807e+00  8.75500858e-01  8.71598959e-01 ...  1.09325898e+00
#      1.34881330e+00  7.35510945e-01]
#    [ 1.19533300e+00  8.85511637e-01  8.34304094e-01 ...  1.13381338e+00
#      1.46855509e+00  7.32217252e-01]
#    [ 1.20987022e+00  1.01331425e+00  9.80067670e-01 ...  1.12134886e+00
#      1.11074448e+00  7.06611931e-01]]
#
#   [[ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#      0.00000000e+00  0.00000000e+00]
#    [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#      0.00000000e+00  0.00000000e+00]
#    [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#      0.00000000e+00  0.00000000e+00]
#    ...
#    [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#      0.00000000e+00  0.00000000e+00]
#    [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#      0.00000000e+00  0.00000000e+00]
#    [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#      0.00000000e+00  0.00000000e+00]]
#
#   ...
#
#   [[ 8.77879202e-01  6.75952792e-01  6.48263216e-01 ...  6.81065977e-01
#      4.44854558e-01  3.59773844e-01]
#    [ 8.47965658e-01  6.75977468e-01  6.54182076e-01 ...  6.25428498e-01
#      3.54075909e-01  2.64752239e-01]
#    [ 8.61555398e-01  6.89867020e-01  6.54298067e-01 ...  5.94536364e-01
#      3.27116311e-01  3.30490917e-01]
#    ...
#    [ 9.06555414e-01  7.88036346e-01  7.29823291e-01 ...  6.28309548e-01
#      3.68149251e-01  4.69601840e-01]
#    [ 9.11527812e-01  8.18775892e-01  7.45070636e-01 ...  6.27324522e-01
#      3.34542155e-01  4.23154294e-01]
#    [ 1.06192648e+00  1.09642756e+00  1.05422747e+00 ...  1.11072469e+00
#      6.79441690e-01  6.93181217e-01]]
#
#   [[ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  9.54945982e-01
#      1.28766701e-01  5.59589148e-01]
#    [ 0.00000000e+00  1.40145971e-02  1.02073178e-01 ...  1.27802324e+00
#      3.91637892e-01  6.10658288e-01]
#    [ 0.00000000e+00  1.77221373e-02  2.33566612e-02 ...  1.26465511e+00
#      3.84868145e-01  6.65387928e-01]
#    ...
#    [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  8.65054190e-01
#      3.54200304e-01  3.18467379e-01]
#    [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  9.40660715e-01
#      6.03052795e-01  4.64264631e-01]
#    [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  4.65082616e-01
#      7.06333593e-02  5.43201491e-02]]
#
#   [[ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#      0.00000000e+00  0.00000000e+00]
#    [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#      0.00000000e+00  0.00000000e+00]
#    [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#      0.00000000e+00  0.00000000e+00]
#    ...
#    [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#      0.00000000e+00  0.00000000e+00]
#    [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#      0.00000000e+00  0.00000000e+00]
#    [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#      0.00000000e+00  0.00000000e+00]]]
#
#
#  [[[ 6.36782944e-01  6.57752633e-01  6.62095308e-01 ...  7.05044925e-01
#      6.77938521e-01  7.08773375e-01]
#    [ 6.07075870e-01  3.73920500e-01  3.64671975e-01 ...  4.70861554e-01
#      5.03735304e-01  3.37006718e-01]
#    [ 6.69469297e-01  4.29837823e-01  3.63295108e-01 ...  7.44616628e-01
#      7.72649467e-01  4.18084025e-01]
#    ...
#    [ 7.15985358e-01  8.89201239e-02  3.58424485e-01 ...  6.79961503e-01
#      7.07338512e-01  3.82992700e-02]
#    [ 9.03454602e-01  0.00000000e+00  3.85678947e-01 ...  5.88832557e-01
#      2.21341312e-01  0.00000000e+00]
#    [ 1.16783583e+00  0.00000000e+00  4.53976274e-01 ...  6.82869554e-01
#      5.62779725e-01  0.00000000e+00]]
#
#   [[ 1.02374470e+00  7.45709598e-01  7.47420371e-01 ...  1.72277898e-01
#      2.60645121e-01  5.34537911e-01]
#    [ 8.69811296e-01  6.84458375e-01  6.94887817e-01 ...  6.71315491e-01
#      9.09789324e-01  4.01345819e-01]
#    [ 8.47140908e-01  6.86540723e-01  6.72420859e-01 ...  8.37647736e-01
#      8.13040495e-01  3.88535827e-01]
#    ...
#    [ 1.80772102e+00  7.74530649e-01  1.18768024e+00 ...  1.24130285e+00
#      1.31257427e+00  1.27455699e+00]
#    [ 1.43743145e+00  6.77458286e-01  1.44444370e+00 ...  1.11033463e+00
#      1.20808434e+00  9.99422133e-01]
#    [ 9.15643156e-01  9.28819478e-01  9.96394157e-01 ...  1.09751499e+00
#      1.10478759e+00  7.28457689e-01]]
#
#   [[ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#      0.00000000e+00  0.00000000e+00]
#    [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#      0.00000000e+00  0.00000000e+00]
#    [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#      0.00000000e+00  0.00000000e+00]
#    ...
#    [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#      0.00000000e+00  0.00000000e+00]
#    [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#      0.00000000e+00  0.00000000e+00]
#    [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#      0.00000000e+00  0.00000000e+00]]
#
#   ...
#
#   [[ 1.17777562e+00  1.06603646e+00  1.08423352e+00 ...  9.08665121e-01
#      6.60035968e-01  3.71290684e-01]
#    [ 1.09075928e+00  1.03867543e+00  1.02528811e+00 ...  5.55947304e-01
#      4.78500366e-01  5.96356452e-01]
#    [ 1.06442523e+00  1.03218710e+00  1.02258134e+00 ...  8.18330586e-01
#      7.40503252e-01  7.61547208e-01]
#    ...
#    [ 7.72060335e-01  1.30513513e+00  7.73615718e-01 ...  2.19121480e+00
#      1.86835694e+00  8.88405323e-01]
#    [ 1.13589907e+00  1.27964854e+00  9.06346738e-01 ...  1.88317609e+00
#      1.90927660e+00  7.87882984e-01]
#    [ 1.55223811e+00  1.37246251e+00  1.30009329e+00 ...  2.03016734e+00
#      2.07814479e+00  1.75473666e+00]]
#
#   [[ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#      3.18532437e-01  1.09824908e+00]
#    [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  1.37260270e+00
#      6.56300008e-01  4.82917011e-01]
#    [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  8.62653792e-01
#      7.48930693e-01  3.35461199e-01]
#    ...
#    [ 0.00000000e+00  3.95982563e-01  2.38262132e-01 ...  0.00000000e+00
#      0.00000000e+00  3.21122445e-02]
#    [ 0.00000000e+00  1.44711629e-01  0.00000000e+00 ...  0.00000000e+00
#      0.00000000e+00  3.17469239e-01]
#    [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#      0.00000000e+00  1.03624411e-01]]
#
#   [[ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#      0.00000000e+00  0.00000000e+00]
#    [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#      0.00000000e+00  0.00000000e+00]
#    [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#      0.00000000e+00  0.00000000e+00]
#    ...
#    [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#      0.00000000e+00  0.00000000e+00]
#    [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#      0.00000000e+00  0.00000000e+00]
#    [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#      0.00000000e+00  0.00000000e+00]]]
#
#
#  ...
#
#
#  [[[ 6.77163482e-01  5.87818742e-01  5.84165275e-01 ...  5.58386385e-01
#      9.09717858e-01  7.73265243e-01]
#    [ 8.76109242e-01  6.75917268e-01  6.80884600e-01 ...  0.00000000e+00
#      1.11954041e-01  5.29474765e-03]
#    [ 1.53873968e+00  6.07241154e-01  1.50757611e-01 ...  0.00000000e+00
#      4.38728958e-01  3.24928403e-01]
#    ...
#    [ 1.10733628e+00  9.37736571e-01  3.23839724e-01 ...  3.54718238e-01
#      4.89867181e-01  5.81058800e-01]
#    [ 4.00933504e-01  5.25285244e-01  5.18229961e-01 ...  6.80893481e-01
#      8.47623229e-01  4.90235746e-01]
#    [ 1.15205121e+00  3.44864488e-01  4.96884733e-01 ...  5.90345800e-01
#      7.85738349e-01  7.07928836e-01]]
#
#   [[ 8.18530321e-01  6.43642783e-01  6.71642900e-01 ...  1.96416974e-01
#      4.81713802e-01  4.32558805e-01]
#    [ 4.67720181e-01  3.74343365e-01  5.00557244e-01 ...  3.02237630e-01
#      1.65090859e-01  4.28514570e-01]
#    [ 1.19923830e+00  1.12367141e+00  1.02635455e+00 ...  2.59220839e-01
#      5.75451136e-01  1.91665590e-01]
#    ...
#    [ 2.18036830e-01  6.22852743e-01  9.60406303e-01 ...  7.81664550e-01
#      8.95503163e-01  4.50817019e-01]
#    [ 1.12604523e+00  1.25002933e+00  1.30280399e+00 ...  8.81794035e-01
#      1.00556302e+00  5.99748373e-01]
#    [ 9.31122184e-01  1.08739245e+00  1.08854914e+00 ...  7.24317551e-01
#      8.11571598e-01  6.79703176e-01]]
#
#   [[ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#      0.00000000e+00  0.00000000e+00]
#    [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#      0.00000000e+00  0.00000000e+00]
#    [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#      0.00000000e+00  0.00000000e+00]
#    ...
#    [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#      0.00000000e+00  0.00000000e+00]
#    [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#      0.00000000e+00  0.00000000e+00]
#    [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#      0.00000000e+00  0.00000000e+00]]
#
#   ...
#
#   [[ 1.34439063e+00  1.23241615e+00  1.32806480e+00 ...  1.58382607e+00
#      1.31483793e+00  1.02201152e+00]
#    [ 1.38825870e+00  1.34584081e+00  1.36938787e+00 ...  1.34386170e+00
#      1.38276267e+00  1.23981380e+00]
#    [ 1.83136415e+00  1.94411719e+00  1.60481167e+00 ...  1.34323049e+00
#      1.06821418e+00  1.01499021e+00]
#    ...
#    [ 9.71593380e-01  8.40104520e-01  1.73039126e+00 ...  1.48984611e+00
#      1.65485752e+00  1.62612581e+00]
#    [ 1.02420998e+00  2.07755756e+00  2.27221918e+00 ...  1.52148366e+00
#      1.64624286e+00  1.47938764e+00]
#    [ 2.01366162e+00  2.47904873e+00  2.53039837e+00 ...  1.67161632e+00
#      2.05992627e+00  2.01705337e+00]]
#
#   [[ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  3.58006001e-01
#      3.13655674e-01  5.90080261e-01]
#    [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#      2.13375881e-01  7.50351250e-01]
#    [ 8.30500901e-01  1.35632563e+00  1.40887547e+00 ...  4.73952681e-01
#      4.17583644e-01  3.79364073e-01]
#    ...
#    [ 5.37013710e-01  1.37425673e+00  0.00000000e+00 ...  0.00000000e+00
#      0.00000000e+00  5.85123971e-02]
#    [ 5.77897504e-02  0.00000000e+00  0.00000000e+00 ...  2.03288496e-01
#      1.83002517e-01  1.74118832e-01]
#    [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#      0.00000000e+00  4.28986311e-01]]
#
#   [[ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#      0.00000000e+00  0.00000000e+00]
#    [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#      0.00000000e+00  0.00000000e+00]
#    [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#      0.00000000e+00  0.00000000e+00]
#    ...
#    [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#      0.00000000e+00  0.00000000e+00]
#    [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#      0.00000000e+00  0.00000000e+00]
#    [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#      0.00000000e+00  0.00000000e+00]]]
#
#
#  [[[ 1.06090295e+00  5.92580378e-01  5.80314577e-01 ...  0.00000000e+00
#      1.11029589e+00  1.86649060e+00]
#    [ 1.01817894e+00  3.47954512e-01  3.92559916e-01 ...  0.00000000e+00
#      1.15234351e+00  2.16951823e+00]
#    [ 9.65036035e-01  6.51834369e-01  6.83591902e-01 ...  7.06572831e-02
#      9.90493178e-01  1.81059384e+00]
#    ...
#    [ 1.27042413e+00  4.03280824e-01  3.58995914e-01 ...  5.58052003e-01
#      0.00000000e+00  6.60493910e-01]
#    [ 1.34259892e+00  4.50608432e-01  2.28449821e-01 ...  6.09484792e-01
#      0.00000000e+00  6.35949194e-01]
#    [ 1.37268972e+00  4.00659859e-01  1.63704425e-01 ...  6.73683524e-01
#      0.00000000e+00  6.74541116e-01]]
#
#   [[ 7.35604882e-01  5.94247103e-01  5.70139170e-01 ...  6.79639339e-01
#      5.19556344e-01  1.04225659e+00]
#    [ 8.69446278e-01  6.54315829e-01  7.40234554e-01 ...  5.69960713e-01
#      6.00532889e-01  9.39908981e-01]
#    [ 8.27281296e-01  6.46733522e-01  5.79334199e-01 ...  3.54093432e-01
#      5.58537662e-01  6.48444295e-01]
#    ...
#    [ 1.07052171e+00  1.02149808e+00  1.04245663e+00 ...  8.00300777e-01
#      6.09610617e-01  3.42488974e-01]
#    [ 9.93194699e-01  1.21592224e+00  9.57509398e-01 ...  9.36210930e-01
#      6.69914246e-01  3.51795852e-01]
#    [ 9.27395880e-01  1.16273165e+00  1.14682436e+00 ...  9.28410232e-01
#      6.15639091e-01  2.92129070e-01]]
#
#   [[ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#      0.00000000e+00  0.00000000e+00]
#    [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#      0.00000000e+00  0.00000000e+00]
#    [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#      0.00000000e+00  0.00000000e+00]
#    ...
#    [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#      0.00000000e+00  0.00000000e+00]
#    [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#      0.00000000e+00  0.00000000e+00]
#    [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#      0.00000000e+00  0.00000000e+00]]
#
#   ...
#
#   [[ 1.80354810e+00  1.70178413e+00  1.74656081e+00 ...  1.64103293e+00
#      1.22487319e+00  2.10337234e+00]
#    [ 1.75687861e+00  1.65214312e+00  1.58959758e+00 ...  1.55734968e+00
#      1.20264268e+00  1.91862762e+00]
#    [ 1.62716746e+00  1.63450491e+00  1.63720357e+00 ...  1.46304572e+00
#      1.21194410e+00  1.89836574e+00]
#    ...
#    [ 1.84044230e+00  2.05728865e+00  2.01900673e+00 ...  1.84663236e+00
#      1.44794309e+00  1.11998701e+00]
#    [ 1.89558554e+00  1.95851111e+00  1.88597548e+00 ...  1.90303648e+00
#      1.59384429e+00  1.07250524e+00]
#    [ 2.16447043e+00  2.10195327e+00  2.09519053e+00 ...  2.09735084e+00
#      1.89525759e+00  1.39232063e+00]]
#
#   [[ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  5.63235462e-01
#      2.65248477e-01  8.99741054e-01]
#    [ 0.00000000e+00  5.42351127e-01  4.35412943e-01 ...  7.86923707e-01
#      5.27666986e-01  1.00918293e+00]
#    [ 4.89975452e-01  1.09670484e+00  9.31040645e-01 ...  6.39961600e-01
#      5.31041563e-01  3.43644261e-01]
#    ...
#    [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#      7.70617664e-01  0.00000000e+00]
#    [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#      6.74731135e-01  0.00000000e+00]
#    [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#      4.86217231e-01  0.00000000e+00]]
#
#   [[ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#      0.00000000e+00  0.00000000e+00]
#    [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#      0.00000000e+00  0.00000000e+00]
#    [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#      0.00000000e+00  0.00000000e+00]
#    ...
#    [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#      0.00000000e+00  0.00000000e+00]
#    [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#      0.00000000e+00  0.00000000e+00]
#    [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#      0.00000000e+00  0.00000000e+00]]]
#
#
#  [[[ 1.06650949e+00  5.83743274e-01  3.22343558e-01 ...  6.31948411e-01
#      5.89175403e-01  7.23372877e-01]
#    [ 1.45783365e+00  1.69122458e-01  5.20717561e-01 ...  7.13321745e-01
#      6.24195039e-01  6.80681646e-01]
#    [ 9.91469264e-01  7.66779602e-01  3.50144863e-01 ...  8.63716543e-01
#      7.25428522e-01  6.63723171e-01]
#    ...
#    [ 9.71058905e-01  1.15674019e+00  7.12726533e-01 ...  1.21641107e-01
#      0.00000000e+00  0.00000000e+00]
#    [ 1.89596558e+00  9.44303572e-01  6.17533803e-01 ...  3.85766745e-01
#      5.16070962e-01  1.56542897e-01]
#    [ 1.74341369e+00  5.62954366e-01  0.00000000e+00 ...  5.17041087e-01
#      6.05821669e-01  4.09698784e-01]]
#
#   [[ 4.73711818e-01  4.73319739e-01  4.76208925e-01 ...  1.14902186e+00
#      1.17443824e+00  5.82461834e-01]
#    [ 9.83592868e-01  8.47056329e-01  7.71501243e-01 ...  1.16532588e+00
#      1.18524301e+00  6.38465881e-01]
#    [ 6.16684496e-01  6.75993085e-01  8.40608776e-01 ...  1.15933442e+00
#      1.21381438e+00  6.63808644e-01]
#    ...
#    [ 1.06292415e+00  1.17089939e+00  1.16890132e+00 ...  1.62397534e-01
#      1.69161111e-01  1.36524886e-01]
#    [ 9.36565995e-01  9.78741050e-01  2.35415548e-01 ...  5.11237264e-01
#      2.02533633e-01  1.94582462e-01]
#    [ 0.00000000e+00  3.25748891e-01  7.74466872e-01 ...  4.30715591e-01
#      3.17853689e-01  2.38227099e-01]]
#
#   [[ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#      0.00000000e+00  0.00000000e+00]
#    [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#      0.00000000e+00  0.00000000e+00]
#    [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#      0.00000000e+00  0.00000000e+00]
#    ...
#    [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#      0.00000000e+00  0.00000000e+00]
#    [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#      0.00000000e+00  0.00000000e+00]
#    [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#      0.00000000e+00  0.00000000e+00]]
#
#   ...
#
#   [[ 2.21211743e+00  2.40701294e+00  2.32843280e+00 ...  2.72199488e+00
#      2.84098506e+00  2.51439786e+00]
#    [ 1.96499729e+00  2.06681943e+00  1.56826341e+00 ...  2.60643888e+00
#      2.69797587e+00  2.34062576e+00]
#    [ 1.31728041e+00  1.49153900e+00  1.32552612e+00 ...  2.57445478e+00
#      2.66941094e+00  2.28801894e+00]
#    ...
#    [ 1.91831803e+00  1.77730823e+00  2.30723190e+00 ...  1.69000542e+00
#      1.00083899e+00  4.43696678e-01]
#    [ 1.64510703e+00  1.27944446e+00  1.95765734e+00 ...  4.75284532e-02
#      8.66308868e-01  9.19410884e-01]
#    [ 1.90539527e+00  1.71524501e+00  1.46661043e+00 ...  2.30264574e-01
#      0.00000000e+00  0.00000000e+00]]
#
#   [[ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#      0.00000000e+00  0.00000000e+00]
#    [ 0.00000000e+00  0.00000000e+00  4.91094366e-02 ...  0.00000000e+00
#      0.00000000e+00  0.00000000e+00]
#    [ 0.00000000e+00  1.40893742e-01  6.21491849e-01 ...  0.00000000e+00
#      0.00000000e+00  0.00000000e+00]
#    ...
#    [ 0.00000000e+00  0.00000000e+00  5.93900084e-01 ...  0.00000000e+00
#      5.77866197e-01  9.42888141e-01]
#    [ 4.53547090e-01  4.92910445e-01  2.37776652e-01 ...  2.03363252e+00
#      1.94518471e+00  1.36195064e+00]
#    [ 1.01818979e+00  0.00000000e+00  1.14172089e+00 ...  1.65250444e+00
#      2.09504938e+00  2.03111410e+00]]
#
#   [[ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#      0.00000000e+00  0.00000000e+00]
#    [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#      0.00000000e+00  0.00000000e+00]
#    [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#      0.00000000e+00  0.00000000e+00]
#    ...
#    [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#      0.00000000e+00  0.00000000e+00]
#    [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#      0.00000000e+00  0.00000000e+00]
#    [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#      0.00000000e+00  0.00000000e+00]]]]

# %%
print('embedding shape:', embedding.shape)
last_img_embedding = embedding[7500:, :, :, ]
print('\n embedding shape of the last image for instance:', last_img_embedding.shape)
# Out:
# embedding shape: torch.Size([7501, 256, 15, 20])
#
#  embedding shape of the last image for instance: torch.Size([1, 256, 15, 20])

# %%
def find_similar_images(test_image, num_sim_images, embedding, device, knn):
    """
    Searches for a similar image given an image and number of similar images to search.
    :param image: Image whose similar images need to be found
    :param num_sim_images: Number of similar images to find (K argument in K-Nearest Neighbors algorithm)
    :param embedding: A (num_sim_images, embedding_dim) embedding of images learnt from auto-encoder.
    :param device: "cuda" or "cpu" device
    :returns: the indices of similar image to the test image
    """
    crop = T.Compose([T.CenterCrop((480, 640))])
    test_image = crop(test_image)
    
    image_tensor = T.ToTensor()(test_image)
    image_tensor = image_tensor.unsqueeze(0)
    image_tensor = image_tensor.to(device)
    with torch.no_grad():
        # the test image whose similar images are required need to be converted to feature representation
        # This line raised error as the model is on GPU, but data is on the CPU. So, we need to send our image tensor to GPU

        #image_embedding = encoder(image_tensor).cpu().detach().numpy()
        image_embedding = encoder(image_tensor).cpu().detach().numpy()
        #print(image_embedding.shape)
        #print('image_embedding:', image_embedding)
        
    flattened_embedding = image_embedding.reshape((image_embedding.shape[0], -1))
    #print(flattened_embedding)

    _, indices = knn.kneighbors(flattened_embedding)
    return indices.tolist()

# %%
test_image_path = "./data/COMP90086_2021_Project_test/test/"
num_sim_images = 1
encode_model_path = "encoder_model.pt"
embedding_path = "data_embedding.npy"

device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")

encoder = ConvEncoder()
# Load the state dict of encoder
encoder.load_state_dict(torch.load(encode_model_path, map_location=device))
encoder.eval()
encoder.to(device)

# Loads the embedding
embedding = np.load(embedding_path)

# Creates K-NN graph
knn = NearestNeighbors(n_neighbors=num_sim_images, metric="cosine")
knn.fit(embedding)

most_similar_images_indices = []

for test_image in test_df['id']:
    print("Image name: ",test_image)
    test_image = Image.open(test_image_path + test_image + '.jpg').convert("RGB")
    
    similiar_images_indices = find_similar_images(test_image, num_sim_images, embedding, device, knn)
    
    # get first element and subtract -1 from index position
    top_match_index = similiar_images_indices[0][0] - 1
    
    print(top_match_index)
    
    # append only top one prediction
    most_similar_images_indices.append(top_match_index)
    #plot_similar_images(indices_list)
# Out:
# Image name:  IMG4287_3
# 954
# Image name:  IMG4288_5
# 7357
# Image name:  IMG4289_5
# 2921
# Image name:  IMG4290_4
# 3124
# Image name:  IMG4291_5
# 5263
# Image name:  IMG4292_3
# 2079
# Image name:  IMG4293_3
# 4255
# Image name:  IMG4294_1
# 5521
# Image name:  IMG4295_1
# 3449
# Image name:  IMG4296_1
# 1764
# Image name:  IMG4297_4
# 5680
# Image name:  IMG4298_1
# 2192
# Image name:  IMG4299_3
# 468
# Image name:  IMG4300_5
# 3184
# Image name:  IMG4301_3
# 2895
# Image name:  IMG4302_2
# 5390
# Image name:  IMG4303_2
# 3127
# Image name:  IMG4304_5
# 1016
# Image name:  IMG4305_5
# 1922
# Image name:  IMG4306_4
# 1016
# Image name:  IMG4307_4
# 5952
# Image name:  IMG4308_3
# 5521
# Image name:  IMG4309_1
# 7129
# Image name:  IMG4310_4
# 695
# Image name:  IMG4311_4
# 2339
# Image name:  IMG4312_2
# 2120
# Image name:  IMG4313_3
# 2749
# Image name:  IMG4314_5
# 3514
# Image name:  IMG4315_5
# 4174
# Image name:  IMG4316_2
# 2975
# Image name:  IMG4317_2
# 429
# Image name:  IMG4318_2
# 5120
# Image name:  IMG4319_2
# 4455
# Image name:  IMG4320_2
# 6372
# Image name:  IMG4321_5
# 6510
# Image name:  IMG4322_4
# 4431
# Image name:  IMG4323_2
# 2749
# Image name:  IMG4324_5
# 2921
# Image name:  IMG4325_4
# 3690
# Image name:  IMG4326_5
# 1552
# Image name:  IMG4327_4
# 3653
# Image name:  IMG4328_4
# 411
# Image name:  IMG4329_1
# 7127
# Image name:  IMG4330_4
# 1207
# Image name:  IMG4331_2
# 334
# Image name:  IMG4332_3
# 3219
# Image name:  IMG4333_2
# 537
# Image name:  IMG4334_3
# 2533
# Image name:  IMG4335_4
# 3219
# Image name:  IMG4336_4
# 705
# Image name:  IMG4337_2
# 5361
# Image name:  IMG4338_3
# 3896
# Image name:  IMG4339_5
# 5931
# Image name:  IMG4340_4
# 7303
# Image name:  IMG4341_5
# 6951
# Image name:  IMG4342_5
# 1016
# Image name:  IMG4343_5
# 5159
# Image name:  IMG4344_5
# 7357
# Image name:  IMG4345_3
# 1207
# Image name:  IMG4346_3
# 5694
# Image name:  IMG4347_5
# 3032
# Image name:  IMG4348_5
# 5655
# Image name:  IMG4349_5
# 7307
# Image name:  IMG4350_2
# 4806
# Image name:  IMG4351_1
# 2222
# Image name:  IMG4352_4
# 1674
# Image name:  IMG4353_3
# 2921
# Image name:  IMG4354_3
# 6510
# Image name:  IMG4355_2
# 6554
# Image name:  IMG4356_2
# 1603
# Image name:  IMG4357_5
# 7057
# Image name:  IMG4358_2
# 1468
# Image name:  IMG4359_3
# 2302
# Image name:  IMG4360_4
# 2238
# Image name:  IMG4361_4
# 5120
# Image name:  IMG4362_2
# 1847
# Image name:  IMG4363_2
# 1965
# Image name:  IMG4364_1
# 3355
# Image name:  IMG4365_4
# 5655
# Image name:  IMG4366_1
# 6661
# Image name:  IMG4367_1
# 6372
# Image name:  IMG4368_2
# 7194
# Image name:  IMG4369_4
# 6951
# Image name:  IMG4370_4
# 3244
# Image name:  IMG4371_1
# 2720
# Image name:  IMG4372_3
# 1077
# Image name:  IMG4373_1
# 1108
# Image name:  IMG4374_3
# 2815
# Image name:  IMG4375_3
# 1830
# Image name:  IMG4376_2
# 4392
# Image name:  IMG4377_1
# 1552
# Image name:  IMG4378_3
# 3888
# Image name:  IMG4379_2
# 1762
# Image name:  IMG4380_4
# 5655
# Image name:  IMG4381_5
# 2093
# Image name:  IMG4382_4
# 7050
# Image name:  IMG4383_3
# 2749
# Image name:  IMG4384_3
# 5222
# Image name:  IMG4385_4
# 5952
# Image name:  IMG4386_3
# 5583
# Image name:  IMG4387_1
# 3330
# Image name:  IMG4388_5
# 5487
# Image name:  IMG4389_5
# 5908
# Image name:  IMG4390_3
# 2961
# Image name:  IMG4391_5
# 4982
# Image name:  IMG4392_1
# 4853
# Image name:  IMG4393_4
# 6460
# Image name:  IMG4394_4
# 2035
# Image name:  IMG4395_4
# 6176
# Image name:  IMG4396_3
# 411
# Image name:  IMG4397_4
# 3662
# Image name:  IMG4398_3
# 2424
# Image name:  IMG4399_1
# 6579
# Image name:  IMG4400_5
# 4806
# Image name:  IMG4401_4
# 5158
# Image name:  IMG4402_3
# 7357
# Image name:  IMG4403_4
# 767
# Image name:  IMG4404_2
# 3000
# Image name:  IMG4405_4
# 4646
# Image name:  IMG4406_2
# 6588
# Image name:  IMG4407_1
# 6092
# Image name:  IMG4408_4
# 3949
# Image name:  IMG4409_2
# 2236
# Image name:  IMG4410_1
# 6372
# Image name:  IMG4411_5
# 1559
# Image name:  IMG4412_2
# 5189
# Image name:  IMG4413_4
# 4364
# Image name:  IMG4414_2
# 1605
# Image name:  IMG4415_2
# 6542
# Image name:  IMG4416_5
# 2749
# Image name:  IMG4417_4
# 3633
# Image name:  IMG4418_5
# 501
# Image name:  IMG4419_3
# 5929
# Image name:  IMG4420_1
# 6372
# Image name:  IMG4421_1
# 3707
# Image name:  IMG4422_2
# 1924
# Image name:  IMG4423_4
# 5259
# Image name:  IMG4424_2
# 4955
# Image name:  IMG4425_3
# 5120
# Image name:  IMG4426_5
# 6995
# Image name:  IMG4427_3
# 2908
# Image name:  IMG4428_5
# 2921
# Image name:  IMG4429_2
# 6951
# Image name:  IMG4430_4
# 2454
# Image name:  IMG4431_1
# 4806
# Image name:  IMG4432_3
# 4656
# Image name:  IMG4433_5
# 2051
# Image name:  IMG4434_3
# 334
# Image name:  IMG4435_5
# 3015
# Image name:  IMG4436_5
# 1207
# Image name:  IMG4437_3
# 3470
# Image name:  IMG4438_2
# 4977
# Image name:  IMG4439_4
# 4392
# Image name:  IMG4440_4
# 4646
# Image name:  IMG4441_3
# 3707
# Image name:  IMG4442_5
# 6372
# Image name:  IMG4443_4
# 1552
# Image name:  IMG4444_5
# 5694
# Image name:  IMG4445_3
# 5705
# Image name:  IMG4446_5
# 3449
# Image name:  IMG4447_4
# 6466
# Image name:  IMG4448_3
# 2808
# Image name:  IMG4449_3
# 5832
# Image name:  IMG4450_3
# 2479
# Image name:  IMG4451_2
# 1016
# Image name:  IMG4452_1
# 3078
# Image name:  IMG4453_2
# 3063
# Image name:  IMG4454_2
# 4904
# Image name:  IMG4455_3
# 1345
# Image name:  IMG4456_2
# 5083
# Image name:  IMG4457_3
# 7080
# Image name:  IMG4458_1
# 7158
# Image name:  IMG4459_3
# 951
# Image name:  IMG4460_1
# 2454
# Image name:  IMG4461_3
# 4982
# Image name:  IMG4462_3
# 7194
# Image name:  IMG4463_1
# 6951
# Image name:  IMG4464_3
# 1924
# Image name:  IMG4465_3
# 7456
# Image name:  IMG4466_1
# 7167
# Image name:  IMG4467_4
# 7167
# Image name:  IMG4468_3
# 3217
# Image name:  IMG4469_4
# 601
# Image name:  IMG4470_1
# 4368
# Image name:  IMG4471_5
# 7052
# Image name:  IMG4472_2
# 4325
# Image name:  IMG4473_1
# 2012
# Image name:  IMG4474_4
# 7139
# Image name:  IMG4475_4
# 2008
# Image name:  IMG4476_4
# 6176
# Image name:  IMG4477_2
# 5976
# Image name:  IMG4478_2
# 3810
# Image name:  IMG4479_5
# 6412
# Image name:  IMG4480_2
# 7108
# Image name:  IMG4481_2
# 3375
# Image name:  IMG4482_3
# 3121
# Image name:  IMG4483_1
# 258
# Image name:  IMG4484_2
# 6372
# Image name:  IMG4485_3
# 2707
# Image name:  IMG4486_2
# 1462
# Image name:  IMG4487_4
# 3000
# Image name:  IMG4488_4
# 5085
# Image name:  IMG4489_5
# 7194
# Image name:  IMG4490_1
# 6158
# Image name:  IMG4491_3
# 411
# Image name:  IMG4492_4
# 5655
# Image name:  IMG4493_3
# 1016
# Image name:  IMG4494_5
# 5120
# Image name:  IMG4495_2
# 5152
# Image name:  IMG4496_5
# 152
# Image name:  IMG4497_1
# 3690
# Image name:  IMG4498_3
# 7303
# Image name:  IMG4499_3
# 7183
# Image name:  IMG4500_3
# 1873
# Image name:  IMG4501_5
# 3970
# Image name:  IMG4502_2
# 3032
# Image name:  IMG4503_3
# 3963
# Image name:  IMG4504_3
# 1283
# Image name:  IMG4505_4
# 4646
# Image name:  IMG4506_4
# 4556
# Image name:  IMG4507_3
# 1559
# Image name:  IMG4508_2
# 1016
# Image name:  IMG4509_2
# 5521
# Image name:  IMG4510_5
# 87
# Image name:  IMG4511_3
# 1338
# Image name:  IMG4512_2
# 4806
# Image name:  IMG4513_1
# 3926
# Image name:  IMG4514_2
# 1016
# Image name:  IMG4515_1
# 1922
# Image name:  IMG4516_2
# 3909
# Image name:  IMG4517_2
# 2116
# Image name:  IMG4518_2
# 5194
# Image name:  IMG4519_5
# 5120
# Image name:  IMG4520_5
# 6673
# Image name:  IMG4521_2
# 1207
# Image name:  IMG4522_4
# 4955
# Image name:  IMG4523_2
# 1552
# Image name:  IMG4524_2
# 2024
# Image name:  IMG4525_3
# 1552
# Image name:  IMG4526_5
# 5178
# Image name:  IMG4527_3
# 7429
# Image name:  IMG4528_4
# 1905
# Image name:  IMG4529_2
# 1283
# Image name:  IMG4530_3
# 1552
# Image name:  IMG4531_1
# 4556
# Image name:  IMG4532_4
# 1873
# Image name:  IMG4533_3
# 1207
# Image name:  IMG4534_5
# 2012
# Image name:  IMG4535_3
# 5825
# Image name:  IMG4536_5
# 1108
# Image name:  IMG4537_2
# 1922
# Image name:  IMG4538_4
# 3110
# Image name:  IMG4539_1
# 5655
# Image name:  IMG4540_3
# 4804
# Image name:  IMG4541_3
# 4280
# Image name:  IMG4542_1
# 1510
# Image name:  IMG4543_1
# 802
# Image name:  IMG4544_3
# 3997
# Image name:  IMG4545_5
# 6580
# Image name:  IMG4546_1
# 6176
# Image name:  IMG4547_5
# 1552
# Image name:  IMG4548_5
# 3518
# Image name:  IMG4549_1
# 7139
# Image name:  IMG4550_4
# 7138
# Image name:  IMG4551_4
# 3134
# Image name:  IMG4552_2
# 7129
# Image name:  IMG4553_1
# 6176
# Image name:  IMG4554_5
# 3330
# Image name:  IMG4555_5
# 6127
# Image name:  IMG4556_3
# 7357
# Image name:  IMG4557_2
# 6661
# Image name:  IMG4558_2
# 5783
# Image name:  IMG4559_4
# 1145
# Image name:  IMG4560_2
# 6176
# Image name:  IMG4561_4
# 3872
# Image name:  IMG4562_5
# 1552
# Image name:  IMG4563_1
# 2492
# Image name:  IMG4564_5
# 4646
# Image name:  IMG4565_4
# 6057
# Image name:  IMG4566_3
# 1468
# Image name:  IMG4567_1
# 5313
# Image name:  IMG4568_2
# 474
# Image name:  IMG4569_3
# 5524
# Image name:  IMG4570_1
# 2565
# Image name:  IMG4571_4
# 601
# Image name:  IMG4572_1
# 4142
# Image name:  IMG4573_5
# 6372
# Image name:  IMG4574_2
# 2257
# Image name:  IMG4575_1
# 274
# Image name:  IMG4576_2
# 3078
# Image name:  IMG4577_3
# 5263
# Image name:  IMG4578_3
# 815
# Image name:  IMG4579_4
# 1207
# Image name:  IMG4580_1
# 3976
# Image name:  IMG4581_2
# 5183
# Image name:  IMG4582_5
# 5775
# Image name:  IMG4583_1
# 4973
# Image name:  IMG4584_2
# 1107
# Image name:  IMG4585_5
# 2869
# Image name:  IMG4586_3
# 1922
# Image name:  IMG4587_4
# 7244
# Image name:  IMG4588_4
# 1559
# Image name:  IMG4589_3
# 1207
# Image name:  IMG4590_1
# 3888
# Image name:  IMG4591_1
# 5521
# Image name:  IMG4592_5
# 6951
# Image name:  IMG4593_4
# 6951
# Image name:  IMG4594_4
# 5655
# Image name:  IMG4595_1
# 6891
# Image name:  IMG4596_4
# 7015
# Image name:  IMG4597_4
# 6409
# Image name:  IMG4598_3
# 3112
# Image name:  IMG4599_1
# 3888
# Image name:  IMG4600_5
# 1108
# Image name:  IMG4601_1
# 3514
# Image name:  IMG4602_4
# 628
# Image name:  IMG4603_2
# 3949
# Image name:  IMG4604_5
# 1468
# Image name:  IMG4605_2
# 5799
# Image name:  IMG4606_3
# 1853
# Image name:  IMG4607_2
# 5216
# Image name:  IMG4608_5
# 6951
# Image name:  IMG4609_3
# 6520
# Image name:  IMG4610_1
# 1922
# Image name:  IMG4611_5
# 3032
# Image name:  IMG4612_3
# 6951
# Image name:  IMG4613_3
# 1552
# Image name:  IMG4614_4
# 3217
# Image name:  IMG4615_1
# 705
# Image name:  IMG4616_5
# 2869
# Image name:  IMG4617_2
# 1830
# Image name:  IMG4618_5
# 5209
# Image name:  IMG4619_5
# 1468
# Image name:  IMG4620_1
# 5348
# Image name:  IMG4621_1
# 2180
# Image name:  IMG4622_1
# 743
# Image name:  IMG4623_2
# 5304
# Image name:  IMG4624_4
# 6176
# Image name:  IMG4625_2
# 6526
# Image name:  IMG4626_3
# 7194
# Image name:  IMG4627_3
# 5521
# Image name:  IMG4628_2
# 2177
# Image name:  IMG4629_3
# 3075
# Image name:  IMG4630_1
# 1922
# Image name:  IMG4631_2
# 1552
# Image name:  IMG4632_2
# 2344
# Image name:  IMG4633_3
# 4431
# Image name:  IMG4634_3
# 4431
# Image name:  IMG4635_3
# 1922
# Image name:  IMG4636_3
# 6776
# Image name:  IMG4637_1
# 2079
# Image name:  IMG4638_3
# 6691
# Image name:  IMG4639_2
# 4646
# Image name:  IMG4640_2
# 2537
# Image name:  IMG4641_2
# 1469
# Image name:  IMG4642_4
# 5521
# Image name:  IMG4643_2
# 6902
# Image name:  IMG4644_5
# 2466
# Image name:  IMG4645_4
# 5194
# Image name:  IMG4646_2
# 661
# Image name:  IMG4647_4
# 1016
# Image name:  IMG4648_2
# 1922
# Image name:  IMG4649_1
# 6372
# Image name:  IMG4650_4
# 2814
# Image name:  IMG4651_3
# 1470
# Image name:  IMG4652_1
# 6951
# Image name:  IMG4653_3
# 7194
# Image name:  IMG4654_4
# 6606
# Image name:  IMG4655_3
# 4181
# Image name:  IMG4656_2
# 1016
# Image name:  IMG4657_5
# 7334
# Image name:  IMG4658_4
# 1016
# Image name:  IMG4659_2
# 1552
# Image name:  IMG4660_5
# 3184
# Image name:  IMG4661_3
# 5569
# Image name:  IMG4662_2
# 4767
# Image name:  IMG4663_2
# 1830
# Image name:  IMG4664_3
# 4806
# Image name:  IMG4665_4
# 1552
# Image name:  IMG4666_2
# 6372
# Image name:  IMG4667_1
# 5521
# Image name:  IMG4668_4
# 6989
# Image name:  IMG4669_2
# 4870
# Image name:  IMG4670_3
# 3375
# Image name:  IMG4671_4
# 1837
# Image name:  IMG4672_2
# 2537
# Image name:  IMG4673_1
# 6412
# Image name:  IMG4674_3
# 7139
# Image name:  IMG4675_2
# 7139
# Image name:  IMG4676_2
# 1468
# Image name:  IMG4677_2
# 1293
# Image name:  IMG4678_1
# 1586
# Image name:  IMG4679_2
# 7086
# Image name:  IMG4680_1
# 5694
# Image name:  IMG4681_4
# 5655
# Image name:  IMG4682_2
# 5228
# Image name:  IMG4683_4
# 591
# Image name:  IMG4684_1
# 738
# Image name:  IMG4685_2
# 3962
# Image name:  IMG4686_1
# 6372
# Image name:  IMG4687_3
# 5346
# Image name:  IMG4688_2
# 4455
# Image name:  IMG4689_4
# 1586
# Image name:  IMG4690_3
# 5012
# Image name:  IMG4691_2
# 2012
# Image name:  IMG4692_1
# 334
# Image name:  IMG4693_5
# 3047
# Image name:  IMG4694_2
# 705
# Image name:  IMG4695_1
# 6510
# Image name:  IMG4696_1
# 3717
# Image name:  IMG4697_2
# 29
# Image name:  IMG4698_4
# 1172
# Image name:  IMG4699_1
# 7316
# Image name:  IMG4700_5
# 5120
# Image name:  IMG4701_4
# 7129
# Image name:  IMG4702_4
# 4806
# Image name:  IMG4703_1
# 1552
# Image name:  IMG4704_3
# 7357
# Image name:  IMG4705_4
# 3951
# Image name:  IMG4706_5
# 7052
# Image name:  IMG4707_2
# 1191
# Image name:  IMG4708_1
# 7293
# Image name:  IMG4709_5
# 3746
# Image name:  IMG4710_3
# 6989
# Image name:  IMG4711_4
# 2479
# Image name:  IMG4712_3
# 1650
# Image name:  IMG4713_3
# 4816
# Image name:  IMG4714_3
# 7244
# Image name:  IMG4715_2
# 4224
# Image name:  IMG4716_1
# 3690
# Image name:  IMG4717_4
# 4982
# Image name:  IMG4718_2
# 7303
# Image name:  IMG4719_5
# 5120
# Image name:  IMG4720_1
# 5655
# Image name:  IMG4721_3
# 4174
# Image name:  IMG4722_2
# 1559
# Image name:  IMG4723_1
# 6819
# Image name:  IMG4724_3
# 3201
# Image name:  IMG4725_1
# 6372
# Image name:  IMG4726_2
# 4104
# Image name:  IMG4727_4
# 4431
# Image name:  IMG4728_1
# 1155
# Image name:  IMG4729_4
# 3662
# Image name:  IMG4730_3
# 1830
# Image name:  IMG4731_2
# 6372
# Image name:  IMG4732_3
# 5583
# Image name:  IMG4733_4
# 1207
# Image name:  IMG4734_5
# 513
# Image name:  IMG4735_3
# 87
# Image name:  IMG4736_2
# 6859
# Image name:  IMG4737_5
# 2895
# Image name:  IMG4738_2
# 7138
# Image name:  IMG4739_3
# 5655
# Image name:  IMG4740_1
# 1651
# Image name:  IMG4741_4
# 1552
# Image name:  IMG4742_4
# 1283
# Image name:  IMG4743_5
# 6795
# Image name:  IMG4744_4
# 2720
# Image name:  IMG4745_1
# 4010
# Image name:  IMG4746_2
# 7138
# Image name:  IMG4747_2
# 4014
# Image name:  IMG4748_4
# 1016
# Image name:  IMG4749_1
# 7108
# Image name:  IMG4750_3
# 6951
# Image name:  IMG4751_2
# 1779
# Image name:  IMG4752_4
# 6372
# Image name:  IMG4753_2
# 5629
# Image name:  IMG4754_4
# 6510
# Image name:  IMG4755_2
# 1552
# Image name:  IMG4756_2
# 7194
# Image name:  IMG4757_3
# 2311
# Image name:  IMG4758_5
# 6292
# Image name:  IMG4759_5
# 3888
# Image name:  IMG4760_2
# 4472
# Image name:  IMG4761_3
# 3217
# Image name:  IMG4762_1
# 3166
# Image name:  IMG4763_4
# 463
# Image name:  IMG4764_4
# 6372
# Image name:  IMG4765_5
# 1922
# Image name:  IMG4766_4
# 3288
# Image name:  IMG4767_5
# 3773
# Image name:  IMG4768_2
# 4646
# Image name:  IMG4769_1
# 4973
# Image name:  IMG4770_1
# 2907
# Image name:  IMG4771_4
# 6057
# Image name:  IMG4772_3
# 3449
# Image name:  IMG4773_1
# 5680
# Image name:  IMG4774_2
# 6372
# Image name:  IMG4775_2
# 5583
# Image name:  IMG4776_4
# 5521
# Image name:  IMG4777_2
# 7365
# Image name:  IMG4778_1
# 570
# Image name:  IMG4779_3
# 7357
# Image name:  IMG4780_1
# 2843
# Image name:  IMG4781_1
# 2454
# Image name:  IMG4782_2
# 1922
# Image name:  IMG4783_2
# 3551
# Image name:  IMG4784_1
# 6951
# Image name:  IMG4785_2
# 4682
# Image name:  IMG4786_5
# 7343
# Image name:  IMG4787_4
# 2331
# Image name:  IMG4788_2
# 2918
# Image name:  IMG4789_2
# 6176
# Image name:  IMG4790_4
# 4768
# Image name:  IMG4791_5
# 6372
# Image name:  IMG4792_3
# 3996
# Image name:  IMG4793_1
# 948
# Image name:  IMG4794_4
# 221
# Image name:  IMG4795_2
# 1016
# Image name:  IMG4796_5
# 2177
# Image name:  IMG4797_4
# 3963
# Image name:  IMG4798_1
# 1830
# Image name:  IMG4799_1
# 4806
# Image name:  IMG4800_3
# 6584
# Image name:  IMG4801_2
# 3355
# Image name:  IMG4802_3
# 3288
# Image name:  IMG4803_5
# 513
# Image name:  IMG4804_2
# 5583
# Image name:  IMG4805_5
# 6372
# Image name:  IMG4806_1
# 3244
# Image name:  IMG4807_5
# 411
# Image name:  IMG4808_2
# 7054
# Image name:  IMG4809_3
# 6884
# Image name:  IMG4810_1
# 5391
# Image name:  IMG4811_3
# 5309
# Image name:  IMG4812_4
# 749
# Image name:  IMG4813_3
# 1552
# Image name:  IMG4814_1
# 2749
# Image name:  IMG4815_5
# 2759
# Image name:  IMG4816_2
# 3633
# Image name:  IMG4817_5
# 6176
# Image name:  IMG4818_2
# 1172
# Image name:  IMG4819_1
# 5914
# Image name:  IMG4820_4
# 2012
# Image name:  IMG4821_1
# 1283
# Image name:  IMG4822_2
# 7194
# Image name:  IMG4823_2
# 3609
# Image name:  IMG4824_1
# 5521
# Image name:  IMG4825_4
# 5261
# Image name:  IMG4826_3
# 4243
# Image name:  IMG4827_2
# 2520
# Image name:  IMG4828_4
# 5917
# Image name:  IMG4829_4
# 749
# Image name:  IMG4830_4
# 482
# Image name:  IMG4831_1
# 3470
# Image name:  IMG4832_4
# 6520
# Image name:  IMG4833_5
# 3148
# Image name:  IMG4834_3
# 3250
# Image name:  IMG4835_2
# 1468
# Image name:  IMG4836_4
# 1552
# Image name:  IMG4837_2
# 2869
# Image name:  IMG4838_2
# 7485
# Image name:  IMG4839_2
# 1922
# Image name:  IMG4840_2
# 5120
# Image name:  IMG4841_4
# 6046
# Image name:  IMG4842_5
# 5710
# Image name:  IMG4843_1
# 852
# Image name:  IMG4844_4
# 3949
# Image name:  IMG4845_5
# 2517
# Image name:  IMG4846_5
# 6372
# Image name:  IMG4847_3
# 4207
# Image name:  IMG4848_2
# 5366
# Image name:  IMG4849_4
# 4455
# Image name:  IMG4850_1
# 6372
# Image name:  IMG4851_4
# 2008
# Image name:  IMG4852_1
# 2979
# Image name:  IMG4853_4
# 4646
# Image name:  IMG4854_1
# 3269
# Image name:  IMG4855_4
# 4346
# Image name:  IMG4856_5
# 6102
# Image name:  IMG4857_4
# 2568
# Image name:  IMG4858_3
# 5391
# Image name:  IMG4859_1
# 6700
# Image name:  IMG4860_5
# 366
# Image name:  IMG4861_4
# 1552
# Image name:  IMG4862_3
# 5548
# Image name:  IMG4863_2
# 2814
# Image name:  IMG4864_5
# 1416
# Image name:  IMG4865_2
# 5680
# Image name:  IMG4866_3
# 2103
# Image name:  IMG4867_5
# 2012
# Image name:  IMG4868_3
# 4931
# Image name:  IMG4869_5
# 3793
# Image name:  IMG4870_4
# 5478
# Image name:  IMG4871_1
# 5309
# Image name:  IMG4872_1
# 1470
# Image name:  IMG4873_5
# 1922
# Image name:  IMG4874_3
# 1585
# Image name:  IMG4875_3
# 1338
# Image name:  IMG4876_3
# 7288
# Image name:  IMG4877_5
# 5135
# Image name:  IMG4878_1
# 4224
# Image name:  IMG4879_5
# 3890
# Image name:  IMG4880_1
# 87
# Image name:  IMG4881_4
# 2177
# Image name:  IMG4882_5
# 7357
# Image name:  IMG4883_2
# 4955
# Image name:  IMG4884_1
# 4116
# Image name:  IMG4885_5
# 5655
# Image name:  IMG4886_1
# 6199
# Image name:  IMG4887_3
# 1207
# Image name:  IMG4888_3
# 7080
# Image name:  IMG4889_5
# 6882
# Image name:  IMG4890_1
# 6554
# Image name:  IMG4891_5
# 7219
# Image name:  IMG4892_3
# 1469
# Image name:  IMG4893_2
# 2008
# Image name:  IMG4894_1
# 5703
# Image name:  IMG4895_5
# 1469
# Image name:  IMG4896_1
# 2921
# Image name:  IMG4897_1
# 3888
# Image name:  IMG4898_5
# 6539
# Image name:  IMG4899_3
# 3134
# Image name:  IMG4900_4
# 411
# Image name:  IMG4901_5
# 1995
# Image name:  IMG4902_2
# 5768
# Image name:  IMG4903_2
# 6983
# Image name:  IMG4904_4
# 2084
# Image name:  IMG4905_2
# 4138
# Image name:  IMG4906_3
# 6372
# Image name:  IMG4907_3
# 4364
# Image name:  IMG4908_3
# 5263
# Image name:  IMG4909_5
# 3917
# Image name:  IMG4910_2
# 7457
# Image name:  IMG4911_5
# 5988
# Image name:  IMG4912_5
# 5348
# Image name:  IMG4913_3
# 3355
# Image name:  IMG4914_5
# 598
# Image name:  IMG4915_2
# 4646
# Image name:  IMG4916_3
# 5737
# Image name:  IMG4917_3
# 1108
# Image name:  IMG4918_3
# 5655
# Image name:  IMG4919_4
# 3375
# Image name:  IMG4920_4
# 652
# Image name:  IMG4921_1
# 5543
# Image name:  IMG4922_4
# 6107
# Image name:  IMG4923_2
# 1585
# Image name:  IMG4924_4
# 4462
# Image name:  IMG4925_5
# 6372
# Image name:  IMG4926_5
# 3288
# Image name:  IMG4927_1
# 1362
# Image name:  IMG4928_3
# 3217
# Image name:  IMG4929_5
# 2008
# Image name:  IMG4930_4
# 5263
# Image name:  IMG4931_3
# 3523
# Image name:  IMG4932_2
# 1518
# Image name:  IMG4933_3
# 3743
# Image name:  IMG4934_5
# 6057
# Image name:  IMG4935_4
# 2180
# Image name:  IMG4936_5
# 1789
# Image name:  IMG4937_5
# 2454
# Image name:  IMG4938_5
# 5655
# Image name:  IMG4939_1
# 2085
# Image name:  IMG4940_5
# 4211
# Image name:  IMG4941_1
# 5159
# Image name:  IMG4942_4
# 5583
# Image name:  IMG4943_3
# 1797
# Image name:  IMG4944_1
# 7413
# Image name:  IMG4945_5
# 2397
# Image name:  IMG4946_5
# 705
# Image name:  IMG4947_3
# 3633
# Image name:  IMG4948_4
# 4897
# Image name:  IMG4949_2
# 2501
# Image name:  IMG4950_2
# 4014
# Image name:  IMG4951_1
# 2921
# Image name:  IMG4952_5
# 1016
# Image name:  IMG4953_3
# 4138
# Image name:  IMG4954_5
# 6510
# Image name:  IMG4955_2
# 3184
# Image name:  IMG4956_4
# 2907
# Image name:  IMG4957_5
# 3888
# Image name:  IMG4958_2
# 1916
# Image name:  IMG4959_1
# 1559
# Image name:  IMG4960_2
# 4138
# Image name:  IMG4961_4
# 4682
# Image name:  IMG4962_4
# 5710
# Image name:  IMG4963_3
# 1108
# Image name:  IMG4964_3
# 6000
# Image name:  IMG4965_1
# 162
# Image name:  IMG4966_3
# 1830
# Image name:  IMG4967_5
# 1819
# Image name:  IMG4968_4
# 6433
# Image name:  IMG4969_4
# 1605
# Image name:  IMG4970_5
# 5655
# Image name:  IMG4971_5
# 1585
# Image name:  IMG4972_4
# 5521
# Image name:  IMG4973_1
# 1470
# Image name:  IMG4974_2
# 1559
# Image name:  IMG4975_3
# 3518
# Image name:  IMG4976_1
# 7412
# Image name:  IMG4977_3
# 2046
# Image name:  IMG4978_2
# 1469
# Image name:  IMG4979_4
# 906
# Image name:  IMG4980_5
# 2501
# Image name:  IMG4981_3
# 2222
# Image name:  IMG4982_5
# 1556
# Image name:  IMG4983_2
# 2177
# Image name:  IMG4984_2
# 7357
# Image name:  IMG4985_4
# 5684
# Image name:  IMG4986_3
# 1552
# Image name:  IMG4987_3
# 1172
# Image name:  IMG4988_2
# 4790
# Image name:  IMG4989_4
# 6495
# Image name:  IMG4990_2
# 5309
# Image name:  IMG4991_4
# 5572
# Image name:  IMG4992_5
# 1922
# Image name:  IMG4993_1
# 1469
# Image name:  IMG4994_5
# 1873
# Image name:  IMG4995_2
# 6372
# Image name:  IMG4996_5
# 2352
# Image name:  IMG4997_3
# 3217
# Image name:  IMG4998_2
# 5655
# Image name:  IMG4999_1
# 3963
# Image name:  IMG5000_5
# 1338
# Image name:  IMG5001_1
# 4426
# Image name:  IMG5002_3
# 5521
# Image name:  IMG5003_5
# 2277
# Image name:  IMG5004_4
# 5404
# Image name:  IMG5005_5
# 5106
# Image name:  IMG5006_3
# 5338
# Image name:  IMG5007_5
# 4372
# Image name:  IMG5008_3
# 2537
# Image name:  IMG5009_3
# 7357
# Image name:  IMG5010_1
# 6176
# Image name:  IMG5011_2
# 4682
# Image name:  IMG5012_2
# 6989
# Image name:  IMG5013_4
# 7052
# Image name:  IMG5014_2
# 6510
# Image name:  IMG5015_4
# 6653
# Image name:  IMG5016_3
# 7057
# Image name:  IMG5017_3
# 1283
# Image name:  IMG5018_3
# 5338
# Image name:  IMG5019_2
# 468
# Image name:  IMG5020_3
# 3429
# Image name:  IMG5021_1
# 2523
# Image name:  IMG5022_5
# 3339
# Image name:  IMG5023_4
# 3999
# Image name:  IMG5024_5
# 1469
# Image name:  IMG5025_5
# 3337
# Image name:  IMG5026_5
# 1552
# Image name:  IMG5027_5
# 1922
# Image name:  IMG5028_5
# 29
# Image name:  IMG5029_1
# 1455
# Image name:  IMG5030_2
# 6520
# Image name:  IMG5031_3
# 7412
# Image name:  IMG5032_2
# 7138
# Image name:  IMG5033_2
# 6604
# Image name:  IMG5034_5
# 426
# Image name:  IMG5035_3
# 1016
# Image name:  IMG5036_3
# 3016
# Image name:  IMG5037_5
# 5309
# Image name:  IMG5038_1
# 5001
# Image name:  IMG5039_3
# 3063
# Image name:  IMG5040_3
# 7138
# Image name:  IMG5041_1
# 1922
# Image name:  IMG5042_2
# 501
# Image name:  IMG5043_1
# 905
# Image name:  IMG5044_1
# 2869
# Image name:  IMG5045_4
# 3888
# Image name:  IMG5046_1
# 6372
# Image name:  IMG5047_3
# 1207
# Image name:  IMG5048_2
# 1741
# Image name:  IMG5049_2
# 1552
# Image name:  IMG5050_1
# 840
# Image name:  IMG5051_5
# 2459
# Image name:  IMG5052_4
# 1922
# Image name:  IMG5053_3
# 840
# Image name:  IMG5054_2
# 1830
# Image name:  IMG5055_4
# 5710
# Image name:  IMG5056_4
# 272
# Image name:  IMG5057_4
# 5655
# Image name:  IMG5058_4
# 1016
# Image name:  IMG5059_1
# 1830
# Image name:  IMG5060_3
# 652
# Image name:  IMG5061_1
# 5203
# Image name:  IMG5062_2
# 5263
# Image name:  IMG5063_3
# 3438
# Image name:  IMG5064_3
# 5655
# Image name:  IMG5065_3
# 6860
# Image name:  IMG5066_4
# 4688
# Image name:  IMG5067_4
# 5963
# Image name:  IMG5068_3
# 6691
# Image name:  IMG5069_4
# 3355
# Image name:  IMG5070_3
# 2454
# Image name:  IMG5071_2
# 3514
# Image name:  IMG5072_4
# 4431
# Image name:  IMG5073_5
# 2079
# Image name:  IMG5074_4
# 5521
# Image name:  IMG5075_3
# 2537
# Image name:  IMG5076_2
# 3063
# Image name:  IMG5077_3
# 6372
# Image name:  IMG5078_2
# 1922
# Image name:  IMG5079_5
# 5120
# Image name:  IMG5080_5
# 6346
# Image name:  IMG5081_5
# 609
# Image name:  IMG5082_3
# 5694
# Image name:  IMG5083_1
# 1830
# Image name:  IMG5084_3
# 5655
# Image name:  IMG5085_2
# 1552
# Image name:  IMG5086_1
# 2749
# Image name:  IMG5087_5
# 5655
# Image name:  IMG5088_1
# 7145
# Image name:  IMG5089_1
# 325
# Image name:  IMG5090_1
# 6369
# Image name:  IMG5091_4
# 5808
# Image name:  IMG5092_2
# 1972
# Image name:  IMG5093_5
# 6795
# Image name:  IMG5094_4
# 7063
# Image name:  IMG5095_4
# 2192
# Image name:  IMG5096_4
# 2884
# Image name:  IMG5097_1
# 1207
# Image name:  IMG5098_1
# 7138
# Image name:  IMG5099_5
# 6010
# Image name:  IMG5100_5
# 5263
# Image name:  IMG5101_5
# 14
# Image name:  IMG5102_3
# 3707
# Image name:  IMG5103_4
# 1016
# Image name:  IMG5104_5
# 5521
# Image name:  IMG5105_5
# 5309
# Image name:  IMG5106_1
# 4849
# Image name:  IMG5107_5
# 5120
# Image name:  IMG5108_5
# 1105
# Image name:  IMG5109_3
# 6554
# Image name:  IMG5110_3
# 6372
# Image name:  IMG5111_2
# 3470
# Image name:  IMG5112_5
# 7407
# Image name:  IMG5113_4
# 3184
# Image name:  IMG5114_1
# 418
# Image name:  IMG5115_1
# 7194
# Image name:  IMG5116_3
# 1016
# Image name:  IMG5117_4
# 3110
# Image name:  IMG5118_1
# 6510
# Image name:  IMG5119_1
# 4381
# Image name:  IMG5120_4
# 7129
# Image name:  IMG5121_4
# 1571
# Image name:  IMG5122_5
# 4928
# Image name:  IMG5123_2
# 2427
# Image name:  IMG5124_3
# 282
# Image name:  IMG5125_2
# 661
# Image name:  IMG5126_3
# 2008
# Image name:  IMG5127_2
# 5483
# Image name:  IMG5128_2
# 2710
# Image name:  IMG5129_5
# 5390
# Image name:  IMG5130_5
# 3470
# Image name:  IMG5131_3
# 6931
# Image name:  IMG5132_4
# 3889
# Image name:  IMG5133_2
# 6606
# Image name:  IMG5134_2
# 4682
# Image name:  IMG5135_5
# 601
# Image name:  IMG5136_5
# 1831
# Image name:  IMG5137_1
# 661
# Image name:  IMG5138_4
# 2814
# Image name:  IMG5139_1
# 1468
# Image name:  IMG5140_5
# 2749
# Image name:  IMG5141_2
# 1283
# Image name:  IMG5142_2
# 501
# Image name:  IMG5143_5
# 2165
# Image name:  IMG5144_4
# 6856
# Image name:  IMG5145_3
# 6510
# Image name:  IMG5146_3
# 4181
# Image name:  IMG5147_1
# 1016
# Image name:  IMG5148_2
# 1338
# Image name:  IMG5149_3
# 1965
# Image name:  IMG5150_1
# 7358
# Image name:  IMG5151_1
# 1469
# Image name:  IMG5152_3
# 4472
# Image name:  IMG5153_3
# 939
# Image name:  IMG5154_5
# 4392
# Image name:  IMG5155_1
# 1559
# Image name:  IMG5156_3
# 1329
# Image name:  IMG5157_5
# 902
# Image name:  IMG5158_1
# 951
# Image name:  IMG5159_4
# 3999
# Image name:  IMG5160_5
# 5521
# Image name:  IMG5161_4
# 3846
# Image name:  IMG5162_3
# 1830
# Image name:  IMG5163_4
# 1651
# Image name:  IMG5164_1
# 5703
# Image name:  IMG5165_1
# 1469
# Image name:  IMG5166_1
# 2158
# Image name:  IMG5167_5
# 6372
# Image name:  IMG5168_3
# 1207
# Image name:  IMG5169_2
# 2982
# Image name:  IMG5170_5
# 1963
# Image name:  IMG5171_3
# 5654
# Image name:  IMG5172_4
# 1922
# Image name:  IMG5173_3
# 5676
# Image name:  IMG5174_5
# 5583
# Image name:  IMG5175_2
# 1016
# Image name:  IMG5176_3
# 4973
# Image name:  IMG5177_1
# 6499
# Image name:  IMG5178_3
# 537
# Image name:  IMG5179_1
# 5929
# Image name:  IMG5180_4
# 859
# Image name:  IMG5181_2
# 2079
# Image name:  IMG5182_1
# 463
# Image name:  IMG5183_1
# 1922
# Image name:  IMG5184_1
# 2454
# Image name:  IMG5185_3
# 1284
# Image name:  IMG5186_5
# 6539
# Image name:  IMG5187_2
# 713
# Image name:  IMG5188_2
# 3184
# Image name:  IMG5189_3
# 1552
# Image name:  IMG5190_3
# 2537
# Image name:  IMG5191_4
# 3875
# Image name:  IMG5192_3
# 1922
# Image name:  IMG5193_5
# 4646
# Image name:  IMG5194_1
# 4556
# Image name:  IMG5195_5
# 5106
# Image name:  IMG5196_5
# 1105
# Image name:  IMG5197_3
# 2814
# Image name:  IMG5198_2
# 3063
# Image name:  IMG5199_5
# 3875
# Image name:  IMG5200_2
# 3609
# Image name:  IMG5201_5
# 1559
# Image name:  IMG5202_5
# 1016
# Image name:  IMG5203_5
# 3403
# Image name:  IMG5204_2
# 4138
# Image name:  IMG5205_3
# 6676
# Image name:  IMG5206_2
# 2423
# Image name:  IMG5207_1
# 5120
# Image name:  IMG5208_3
# 6372
# Image name:  IMG5209_4
# 5655
# Image name:  IMG5210_1
# 3857
# Image name:  IMG5211_1
# 1892
# Image name:  IMG5212_2
# 5366
# Image name:  IMG5213_5
# 5521
# Image name:  IMG5214_4
# 1016
# Image name:  IMG5215_1
# 760
# Image name:  IMG5216_4
# 3044
# Image name:  IMG5217_1
# 5120
# Image name:  IMG5218_4
# 2875
# Image name:  IMG5219_5
# 1426
# Image name:  IMG5220_3
# 3816
# Image name:  IMG5221_4
# 2921
# Image name:  IMG5222_3
# 2537
# Image name:  IMG5223_5
# 4138
# Image name:  IMG5224_5
# 501
# Image name:  IMG5225_2
# 2103
# Image name:  IMG5226_4
# 7029
# Image name:  IMG5227_3
# 2523
# Image name:  IMG5228_1
# 2814
# Image name:  IMG5229_1
# 5120
# Image name:  IMG5230_1
# 3429
# Image name:  IMG5231_3
# 3217
# Image name:  IMG5232_2
# 3544
# Image name:  IMG5233_2
# 2921
# Image name:  IMG5234_3
# 3797
# Image name:  IMG5235_4
# 1552
# Image name:  IMG5236_4
# 2424
# Image name:  IMG5237_1
# 5583
# Image name:  IMG5238_2
# 7334
# Image name:  IMG5239_3
# 5207
# Image name:  IMG5240_4
# 6372
# Image name:  IMG5241_5
# 3963
# Image name:  IMG5242_4
# 5680
# Image name:  IMG5243_3
# 6372
# Image name:  IMG5244_3
# 4015
# Image name:  IMG5245_1
# 6588
# Image name:  IMG5246_4
# 5655
# Image name:  IMG5247_3
# 5390
# Image name:  IMG5248_3
# 6795
# Image name:  IMG5249_2
# 1552
# Image name:  IMG5250_1
# 6092
# Image name:  IMG5251_3
# 661
# Image name:  IMG5252_5
# 2084
# Image name:  IMG5253_5
# 4431
# Image name:  IMG5254_5
# 2353
# Image name:  IMG5255_5
# 1076
# Image name:  IMG5256_2
# 1016
# Image name:  IMG5257_1
# 1207
# Image name:  IMG5258_2
# 566
# Image name:  IMG5259_1
# 2217
# Image name:  IMG5260_4
# 4232
# Image name:  IMG5261_1
# 2321
# Image name:  IMG5262_2
# 1468
# Image name:  IMG5263_2
# 7405
# Image name:  IMG5264_4
# 5680
# Image name:  IMG5265_2
# 1462
# Image name:  IMG5266_5
# 5655
# Image name:  IMG5267_1
# 7059
# Image name:  IMG5268_4
# 4973
# Image name:  IMG5269_3
# 5583
# Image name:  IMG5270_5
# 7357
# Image name:  IMG5271_4
# 6989
# Image name:  IMG5272_1
# 3063
# Image name:  IMG5273_3
# 5407
# Image name:  IMG5274_2
# 2830
# Image name:  IMG5275_4
# 1922
# Image name:  IMG5276_2
# 3312
# Image name:  IMG5277_3
# 6372
# Image name:  IMG5278_5
# 5376
# Image name:  IMG5279_5
# 2103
# Image name:  IMG5280_1
# 2164
# Image name:  IMG5281_1
# 7194
# Image name:  IMG5282_1
# 1207
# Image name:  IMG5283_5
# 5404
# Image name:  IMG5284_3
# 5120
# Image name:  IMG5285_1
# 1790
# Image name:  IMG5286_3
# 3949
# Image name:  IMG5287_3
# 2749
# Image name:  IMG5288_5
# 2158
# Image name:  IMG5289_2
# 3375
# Image name:  IMG5290_2
# 5216
# Image name:  IMG5291_2
# 2749
# Image name:  IMG5292_5
# 4232
# Image name:  IMG5293_3
# 6691
# Image name:  IMG5294_1
# 5404
# Image name:  IMG5295_5
# 2526
# Image name:  IMG5296_2
# 3848
# Image name:  IMG5297_5
# 1830
# Image name:  IMG5298_5
# 3736
# Image name:  IMG5299_4
# 2352
# Image name:  IMG5300_2
# 4867
# Image name:  IMG5301_4
# 3262
# Image name:  IMG5302_3
# 6654
# Image name:  IMG5303_5
# 1965
# Image name:  IMG5304_4
# 5399
# Image name:  IMG5305_5
# 2921
# Image name:  IMG5306_3
# 3217
# Image name:  IMG5307_5
# 1122
# Image name:  IMG5308_2
# 2895
# Image name:  IMG5309_2
# 5655
# Image name:  IMG5310_2
# 3640
# Image name:  IMG5311_3
# 798
# Image name:  IMG5312_4
# 6989
# Image name:  IMG5313_4
# 5120
# Image name:  IMG5314_5
# 4185
# Image name:  IMG5315_2
# 5808
# Image name:  IMG5316_1
# 1391
# Image name:  IMG5317_1
# 3063
# Image name:  IMG5318_3
# 1283
# Image name:  IMG5319_1
# 5694
# Image name:  IMG5320_2
# 7194
# Image name:  IMG5321_2
# 3355
# Image name:  IMG5322_4
# 5710
# Image name:  IMG5323_3
# 3662
# Image name:  IMG5324_5
# 5710
# Image name:  IMG5325_4
# 1179
# Image name:  IMG5326_5
# 3063
# Image name:  IMG5327_3
# 2424
# Image name:  IMG5328_1
# 2366
# Image name:  IMG5329_1
# 537
# Image name:  IMG5330_3
# 5710
# Image name:  IMG5331_1
# 1922
# Image name:  IMG5332_1
# 7412
# Image name:  IMG5333_2
# 767
# Image name:  IMG5334_3
# 87
# Image name:  IMG5335_2
# 2751
# Image name:  IMG5336_5
# 6817
# Image name:  IMG5337_1
# 1468
# Image name:  IMG5338_4
# 2109
# Image name:  IMG5339_1
# 6842
# Image name:  IMG5340_2
# 1008
# Image name:  IMG5341_4
# 1762
# Image name:  IMG5342_2
# 4381
# Image name:  IMG5343_2
# 5390
# Image name:  IMG5344_5
# 7412
# Image name:  IMG5345_2
# 4806
# Image name:  IMG5346_1
# 4806
# Image name:  IMG5347_5
# 1241
# Image name:  IMG5348_4
# 6951
# Image name:  IMG5349_3
# 852
# Image name:  IMG5350_1
# 5710
# Image name:  IMG5351_3
# 585
# Image name:  IMG5352_5
# 3963
# Image name:  IMG5353_1
# 3609
# Image name:  IMG5354_4
# 7303
# Image name:  IMG5355_5
# 3219
# Image name:  IMG5356_3
# 7194
# Image name:  IMG5357_2
# 1108
# Image name:  IMG5358_5
# 5655
# Image name:  IMG5359_5
# 1016
# Image name:  IMG5360_5
# 2749
# Image name:  IMG5361_1
# 1586
# Image name:  IMG5362_2
# 942
# Image name:  IMG5363_1
# 505
# Image name:  IMG5364_1
# 7057
# Image name:  IMG5365_4
# 3624
# Image name:  IMG5366_4
# 4820
# Image name:  IMG5367_4
# 6189
# Image name:  IMG5368_2
# 7080
# Image name:  IMG5369_2
# 7357
# Image name:  IMG5370_2
# 411
# Image name:  IMG5371_2
# 4955
# Image name:  IMG5372_5
# 5655
# Image name:  IMG5373_4
# 3743
# Image name:  IMG5374_4
# 3330
# Image name:  IMG5375_4
# 3375
# Image name:  IMG5376_2
# 705
# Image name:  IMG5377_4
# 4973
# Image name:  IMG5378_1
# 2079
# Image name:  IMG5379_5
# 411
# Image name:  IMG5380_1
# 1965
# Image name:  IMG5381_3
# 1922
# Image name:  IMG5382_2
# 6951
# Image name:  IMG5383_1
# 2814
# Image name:  IMG5384_4
# 601
# Image name:  IMG5385_2
# 3717
# Image name:  IMG5386_2
# 4607
# Image name:  IMG5387_2
# 2158
# Image name:  IMG5388_3
# 6499
# Image name:  IMG5389_2
# 3819
# Image name:  IMG5390_4
# 1700
# Image name:  IMG5391_4
# 5399
# Image name:  IMG5392_1
# 3949
# Image name:  IMG5393_2
# 1469
# Image name:  IMG5394_3
# 1972
# Image name:  IMG5395_1
# 1108
# Image name:  IMG5396_2
# 4138
# Image name:  IMG5397_3
# 2707
# Image name:  IMG5398_4
# 703
# Image name:  IMG5399_4
# 2691
# Image name:  IMG5400_3
# 1922
# Image name:  IMG5401_5
# 6990
# Image name:  IMG5402_5
# 6896
# Image name:  IMG5403_1
# 7311
# Image name:  IMG5404_4
# 5366
# Image name:  IMG5405_5
# 3620
# Image name:  IMG5406_2
# 4556
# Image name:  IMG5407_2
# 3032
# Image name:  IMG5408_2
# 705
# Image name:  IMG5409_2
# 5159
# Image name:  IMG5410_1
# 6951
# Image name:  IMG5411_4
# 3587
# Image name:  IMG5412_4
# 6372
# Image name:  IMG5413_4
# 6882
# Image name:  IMG5414_2
# 3063
# Image name:  IMG5415_4
# 5346
# Image name:  IMG5416_5
# 3976
# Image name:  IMG5417_3
# 4892
# Image name:  IMG5418_4
# 7293
# Image name:  IMG5419_4
# 6435
# Image name:  IMG5420_1
# 5521
# Image name:  IMG5421_4
# 6372
# Image name:  IMG5422_1
# 7293
# Image name:  IMG5423_3
# 3694
# Image name:  IMG5424_4
# 4968
# Image name:  IMG5425_4
# 5189
# Image name:  IMG5426_5
# 4273
# Image name:  IMG5427_1
# 5521
# Image name:  IMG5428_2
# 4941
# Image name:  IMG5429_3
# 4997
# Image name:  IMG5430_3
# 5374
# Image name:  IMG5431_3
# 5316
# Image name:  IMG5432_1
# 1965
# Image name:  IMG5433_4
# 3748
# Image name:  IMG5434_1
# 5120
# Image name:  IMG5435_1
# 1016
# Image name:  IMG5436_3
# 4773
# Image name:  IMG5437_3
# 1469
# Image name:  IMG5438_3
# 1571
# Image name:  IMG5439_2
# 3518
# Image name:  IMG5440_1
# 7412
# Image name:  IMG5441_2
# 1516
# Image name:  IMG5442_1
# 2720
# Image name:  IMG5443_3
# 7452
# Image name:  IMG5444_3
# 6951
# Image name:  IMG5445_4
# 1468
# Image name:  IMG5446_1
# 6989
# Image name:  IMG5447_3
# 5799
# Image name:  IMG5448_5
# 3875
# Image name:  IMG5449_1
# 6379
# Image name:  IMG5450_5
# 3116
# Image name:  IMG5451_3
# 4196
# Image name:  IMG5452_3
# 3610
# Image name:  IMG5453_1
# 5120
# Image name:  IMG5454_4
# 5655
# Image name:  IMG5455_3
# 5914
# Image name:  IMG5456_3
# 1468
# Image name:  IMG5457_3
# 4981
# Image name:  IMG5458_5
# 7325
# Image name:  IMG5459_5
# 1310
# Image name:  IMG5460_4
# 6063
# Image name:  IMG5461_4
# 2127
# Image name:  IMG5462_4
# 6372
# Image name:  IMG5463_2
# 1559
# Image name:  IMG5464_3
# 5159
# Image name:  IMG5465_2
# 4100
# Image name:  IMG5466_2
# 1830
# Image name:  IMG5467_2
# 4385
# Image name:  IMG5468_1
# 1586
# Image name:  IMG5469_2
# 5941
# Image name:  IMG5470_3
# 6951
# Image name:  IMG5471_2
# 2921
# Image name:  IMG5472_4
# 4646
# Image name:  IMG5473_1
# 2079
# Image name:  IMG5474_1
# 7446
# Image name:  IMG5475_5
# 852
# Image name:  IMG5476_2
# 6372
# Image name:  IMG5477_5
# 1552
# Image name:  IMG5478_4
# 4255
# Image name:  IMG5479_5
# 4982
# Image name:  IMG5480_4
# 4346
# Image name:  IMG5481_2
# 1283
# Image name:  IMG5482_1
# 347
# Image name:  IMG5483_2
# 5655
# Image name:  IMG5484_4
# 6307
# Image name:  IMG5485_3
# 6372
# Image name:  IMG5486_2
# 6293

# %%
current_id = 7357
train_df.iloc[current_id, 1]
# Out:
# 6.419321919

# %%
preds = []

for current_index in most_similar_images_indices:
    x = train_df.iloc[current_index, 1]
    y = train_df.iloc[current_index, 2]
    pred = (x, y)
    preds.append(pred)

# %%
len(most_similar_images_indices)
# Out:
# 1200

# %% [markdown]
# ## Write submission file

# %%
import csv

test_filenames = []
with open("./data/COMP90086_2021_Project_test/imagenames.csv", newline='') as inputfile:
    reader = csv.reader(inputfile)
    # skip header
    header = next(reader)
    
    for row in reader:
        test_filenames.append(str(row[0]))
    
test_filenames[0]
# Out:
# 'IMG4287_3'

# %%
with open("submission.csv","w",newline="") as csvfile:
    writer=csv.writer(csvfile)
    writer.writerow(["id","x","y"])
    index = 0
    for prediction in preds:
        writer.writerow([test_filenames[index], preds[index][0], preds[index][1]])
        index+=1
